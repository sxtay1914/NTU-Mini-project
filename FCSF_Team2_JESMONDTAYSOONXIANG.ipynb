# %% [markdown]
# ### Student Grouping and Sorting Based on GPA, Gender, and School
# *Team Members*:
# 1. LEE ZHE CHIAN
# 2. JESMOND TAY SOON XIANG
# 3. LEE ZHENG JIE
# 4. KATTA ROHITA
# 5. HTET MOE HAN
#
# *Objectives*:
# Form balanced groups containing 5 students each.

# %% [markdown]
# ### Problem Decomposition
# *Problem Statement*
# sort students from different tutorial groups into smaller groups based on the following requirements.
#    - Each group should have a maximum of five students.
#    - Gender ratio must follow a 3:2 pattern
#    - Each group should contain students having different ranges in their GPA.
#    - Each group should not have more than 2 people from the same school.
#
# *Problem Decomposition Process*
#
# Step 1: Load the CSV file containing student data.
#
# Step 2: Group students by their tutorial group.
#
# Step 3: Classify students into three GPA categories - above average, average, and below average
#
# Step 4: Implement three sorting functions to assign students to groups while respecting gender, GPA, and school constraints.
#
# Step 5: Add the remaining students to the reserved dictionary and use them to fill in remaining spots making sure that the gender and school constraints.
#
# Step 6: If there are still remaining students in reserved dictionary, gpa and school constraints are relaxed. Sorting will be only based on gender.

# %% [markdown]
# ### Data Analysis
# - The data file consists of:
#      - Tutorial Group
#      - Student ID
#      - School
#      - Name
#      - Gender
#      - GPA.

# %% [markdown]
# - Data is loaded into a Python list structure for initial processing and then categorized into dictionaries based on tutorial groups and GPA levels

# %% [markdown]
# ### Pseudocode / Flowchart
# **1st draft of plan**:
# 1. Read CSV File
# - Import data from the CSV file containing student information.
#
# 2. Split by Tutorial Group
# - Separate students into their respective tutorial groups.
#
# 3. Set GPA Benchmark
# - For each tutorial, Calculate the average and range of GPA scores across all students in the group to establish a benchmark.
#
# 4. Split Students by School
# - Within each tutorial group, divide students according to their school.
#
# 5. Classify Students by GPA Level
# - Within each school, categorize students into three subgroups based on GPA
#
# 6. Create three functions. One is used to sort gpa, the other is used to sort school and the last is used to sort gender.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Gender Sort Pseudocode
# 1. Initialize and get group data
#
# 2. For each tutorial group (tut_grp):
#    Calculate the total gender ratio of males to females (e.g., 20 males: 30 females).
#    Determine team gender ratios
#
# 3.  Check if the overall gender ratio can be evenly divided among 10 teams.
# -   If yes:
#     Calculate the exact gender ratio per team (e.g., if the group has 20 males and 30 females, each team should have 2 males and 3 females).
# -   If no:
#     Calculate the minimum ratio per team that approximates an even split.
#     Identify any leftover students by gender (e.g., for a 21 males: 29 females ratio, distribute 2 males and 2 females per team with 1 male and 9 females left over).
#     Split the leftover students as evenly as possible across the 10 teams.
#
# 4. Create and Initialize Teams:
#
#    Set up 10 empty teams, each with a capacity based on the determined gender ratio per team.
#    Assign Students to teams:
#
# -   For each student in the tutorial group:
#     Check each team sequentially to find a suitable spot:
# -   If the team is full:
#     Continue to the next team.
# -   If the team has available spots:
#     Check if adding the student would exceed the team’s gender ratio.
# -   If adding the student exceeds the ratio:
#     Continue to the next team.
# -   If adding the student maintains the gender ratio:
#     Place the student in the team.
#     Break out of the loop and move to the next student.
# 5. End Process:
#    After assigning all students, review the teams to ensure the gender ratios are as balanced as possible.
#
#
# ## Difficulty faced implementing the first plan
# 1. We tried to create functions that sort only one constraint at a time and when we tried to merge it together, we found it impossible to do so.

# %% [markdown]
# **2nd/Final draft of plan**:
# 1. Read CSV File
#
# 2. Split by tutorial groups using dictionary
# - {tutorial: list of studens' data}
#
# 3. Create gpa dictionary:
# - {tutorial group: list of students' data, with gpa as the first element}
# - convert gpa from string to float
#
# 4. Sort gpa in ascending order
# - For each tutorial in the gpa dictionary, sort the student's gpa in ascending order
#
# 5. Grouping students in each tutorial groups into three gpa types:
# - the first 20 students are assigned Below
# - the consecutive studentsa are assigned Average
# - the last 10 students are assigned Above Average
#
# 6. Initialize sorted_dictionary to store the sorted students, reserved dictionary to store students that dont fit the constraints.
#
# 6. First sorting which includes gpa, school and gender constraint
#
# - the fist sorting aims to choose 2 above average, 1 average and 2 below average, while checking the gender constraints(majority gender<=3 and minority gender<=2) and making sure students from same school does not exceed 2.
#
# - if the students do not fit the constraints, they will be added to reserved dictionary from which they will be assessed later.
#
# 7. Second sorting sorts according to the same constraints as the first sorting but this time it is filling up teams with students from the reserved dictionary.
# - For each team in the tutorial group, the function will loop through the reserved dictionary until the team contains 5 members
# - However there may be cases whereby situation is not so ideal that all students are able to meet the constraints, thus there will be leftovers in the reserved dictionary
#
# 8. Final sorting with relaxed constraints
# - Gender constraints are checked only
#
# - If gender constraints cannot be met, students will just be assigned to teams that do not have 5 members from the reserved dictionary
#
# 9. Output as csv file
#
# 10. Analysis of the results using matplotlib
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step 1: Load and Display Data
# This cell loads the CSV data and organizes it into lists for further processing.

# %%
# Cell 1: 
csvlist = []
import csv

# Open the CSV file 
with open("C:\\Users\\jesmo\\OneDrive\\Documents\\records.csv", mode ='r') as file:
    csvFile = csv.reader(file)

    # Append each row of CSV to csvlist as a list
    for lines in csvFile:
        csvlist.append(lines)

# Print the entire CSV data to verify 
print("CSV Data Loaded:", csvlist)
# Out:
# CSV Data Loaded: [['Tutorial Group', 'Student ID', 'School', 'Name', 'Gender', 'CGPA'], ['G-1', '5002', 'CCDS', 'Aarav Singh', 'Male', '4.02'], ['G-1', '3838', 'EEE', 'Aarti Nair', 'Female', '4.05'], ['G-1', '2091', 'EEE', 'Adlan Bin Rahman', 'Male', '4.2'], ['G-1', '288', 'CoB (NBS)', 'Ajay Verma', 'Male', '4.01'], ['G-1', '4479', 'CCDS', 'Amelia Kim', 'Female', '4.11'], ['G-1', '5708', 'SoH', 'Ananya Ramesh', 'Male', '4.2'], ['G-1', '4563', 'WKW SCI', 'Anjali Patel', 'Female', '4.01'], ['G-1', '3989', 'WKW SCI', 'Anthony Liu', 'Male', '4.15'], ['G-1', '2115', 'EEE', 'Anya Kumar', 'Female', '4.03'], ['G-1', '1383', 'CoB (NBS)', 'Areeba Khan', 'Female', '4.19'], ['G-1', '1417', 'CoE', 'Darren Lee', 'Male', '4.12'], ['G-1', '1075', 'CoB (NBS)', 'Felix Yip', 'Male', '4.08'], ['G-1', '3148', 'EEE', 'Gabriel Young', 'Male', '3.88'], ['G-1', '4402', 'CCDS', 'Grace Turner', 'Female', '4.08'], ['G-1', '945', 'MAE', 'Han Li', 'Female', '4.1'], ['G-1', '2230', 'CoB (NBS)', 'Harlow Wang', 'Female', '4.18'], ['G-1', '4520', 'EEE', 'Henry Foster', 'Male', '4.11'], ['G-1', '567', 'CoB (NBS)', 'Isabella Thompson', 'Female', '4.03'], ['G-1', '1841', 'MAE', 'Jett Morales', 'Male', '4.12'], ['G-1', '4576', 'EEE', 'Jie Zhang', 'Male', '4.03'], ['G-1', '5703', 'SPMS', 'Karen Lee', 'Female', '4.12'], ['G-1', '2353', 'SBS', 'Karen Wong', 'Female', '3.95'], ['G-1', '2069', 'SSS', 'Kathy Lau', 'Female', '4.48'], ['G-1', '3861', 'ASE', 'Layla Torres', 'Female', '4.52'], ['G-1', '162', 'SSS', 'Lila Patel', 'Female', '4.07'], ['G-1', '588', 'MAE', 'Lucas Walker', 'Male', '4.06'], ['G-1', '659', 'SSS', 'Maria Ivanovna', 'Female', '4.2'], ['G-1', '4820', 'CoE', 'Meera Singh', 'Female', '4.22'], ['G-1', '2151', 'EEE', 'Mei Hong', 'Female', '4.02'], ['G-1', '235', 'CCDS', 'Ming Zhang', 'Male', '4.06'], ['G-1', '527', 'EEE', 'Mohit Desai', 'Male', '4.06'], ['G-1', '1329', 'NIE', 'Nguyen Van Sam', 'Male', '3.85'], ['G-1', '5119', 'ADM', 'Nhung Vu', 'Female', '4.04'], ['G-1', '809', 'CoB (NBS)', 'Nisha Das', 'Female', '4.26'], ['G-1', '2650', 'SoH', 'Nurul Shafika', 'Female', '4.09'], ['G-1', '4657', 'SoH', 'Oleg Petrovich', 'Male', '4'], ['G-1', '2818', 'CoB (NBS)', 'Oliver Tan', 'Male', '4.09'], ['G-1', '3628', 'EEE', 'Omer Ahmed', 'Male', '4.06'], ['G-1', '1555', 'MAE', 'Prerna Gupta', 'Female', '4.04'], ['G-1', '1271', 'SSS', 'Priya Singh', 'Female', '4.17'], ['G-1', '75', 'CCDS', 'Sakina Ahmed', 'Female', '4.03'], ['G-1', '4338', 'SPMS', 'Sana Jain', 'Female', '4.22'], ['G-1', '71', 'SoH', 'Savannah Taylor', 'Female', '4.19'], ['G-1', '2776', 'CCEB', 'Siddharth Nair', 'Male', '4.14'], ['G-1', '2417', 'SSS', 'Truong Minh Chau', 'Female', '3.88'], ['G-1', '5477', 'SoH', 'Vikram Desai', 'Male', '4.09'], ['G-1', '2326', 'CoB (NBS)', 'Vivi Dwi', 'Female', '3.95'], ['G-1', '3930', 'EEE', 'Xun Wei', 'Female', '4.18'], ['G-1', '1645', 'CoE', 'Zachary Wu', 'Male', '3.93'], ['G-1', '592', 'MSE', 'Zara Chang', 'Female', '4.11'], ['G-10', '3329', 'MAE', 'Adrian Castillo', 'Male', '4.07'], ['G-10', '2581', 'ASE', 'Alyssa Green', 'Female', '3.94'], ['G-10', '594', 'MAE', 'Ananya Singh', 'Female', '4.2'], ['G-10', '560', 'SoH', 'Ayesha Javed', 'Female', '4.09'], ['G-10', '3841', 'SBS', 'Benjamin Turner', 'Male', '4.06'], ['G-10', '5624', 'EEE', 'Cheng Zhang', 'Male', '4.11'], ['G-10', '3794', 'CoB (NBS)', 'Christopher Miller', 'Male', '4.17'], ['G-10', '2253', 'EEE', 'Dante Wu', 'Male', '4.18'], ['G-10', '298', 'MAE', 'Freya Chen', 'Female', '4.09'], ['G-10', '403', 'SoH', 'Hae-Jin Lee', 'Female', '4.52'], ['G-10', '5734', 'MAE', 'Hassan Malik', 'Male', '4.03'], ['G-10', '611', 'SPMS', 'Hendra Mulyana', 'Male', '4.1'], ['G-10', '3051', 'LKCMedicine', 'Hunter Wilson', 'Male', '4.06'], ['G-10', '565', 'SoH', 'Isaiah Scott', 'Male', '4.15'], ['G-10', '223', 'MAE', 'Jaxon Hall', 'Male', '4.12'], ['G-10', '375', 'SBS', 'Kaya Chang', 'Female', '4.05'], ['G-10', '2031', 'CCDS', 'Kendrick Alvarado', 'Male', '4.18'], ['G-10', '5122', 'CCEB', 'Kerry Lim', 'Female', '4.01'], ['G- ...

# %%
# Cell 2: Sort students into tutorial groups in tut_dict as lists (Ex: tutgrp: [])
tut_dict = {}

# Loop through each student entry in csvlist
for i in csvlist:
    if i[0] == 'Tutorial Group':
        continue
    elif i[0] in tut_dict:
        # If the tutorial group already exists, append the student to that group
        tut_dict[i[0]].append(i)
    else:
        # Otherwise, create a new list for this tutorial group
        tut_dict[i[0]] = [i]

print("Tutorial Group G-1 Data:", tut_dict.get('G-1')) #Printing the data a specific tutorial group to verify
# Out:
# Tutorial Group G-1 Data: [['G-1', '5002', 'CCDS', 'Aarav Singh', 'Male', '4.02'], ['G-1', '3838', 'EEE', 'Aarti Nair', 'Female', '4.05'], ['G-1', '2091', 'EEE', 'Adlan Bin Rahman', 'Male', '4.2'], ['G-1', '288', 'CoB (NBS)', 'Ajay Verma', 'Male', '4.01'], ['G-1', '4479', 'CCDS', 'Amelia Kim', 'Female', '4.11'], ['G-1', '5708', 'SoH', 'Ananya Ramesh', 'Male', '4.2'], ['G-1', '4563', 'WKW SCI', 'Anjali Patel', 'Female', '4.01'], ['G-1', '3989', 'WKW SCI', 'Anthony Liu', 'Male', '4.15'], ['G-1', '2115', 'EEE', 'Anya Kumar', 'Female', '4.03'], ['G-1', '1383', 'CoB (NBS)', 'Areeba Khan', 'Female', '4.19'], ['G-1', '1417', 'CoE', 'Darren Lee', 'Male', '4.12'], ['G-1', '1075', 'CoB (NBS)', 'Felix Yip', 'Male', '4.08'], ['G-1', '3148', 'EEE', 'Gabriel Young', 'Male', '3.88'], ['G-1', '4402', 'CCDS', 'Grace Turner', 'Female', '4.08'], ['G-1', '945', 'MAE', 'Han Li', 'Female', '4.1'], ['G-1', '2230', 'CoB (NBS)', 'Harlow Wang', 'Female', '4.18'], ['G-1', '4520', 'EEE', 'Henry Foster', 'Male', '4.11'], ['G-1', '567', 'CoB (NBS)', 'Isabella Thompson', 'Female', '4.03'], ['G-1', '1841', 'MAE', 'Jett Morales', 'Male', '4.12'], ['G-1', '4576', 'EEE', 'Jie Zhang', 'Male', '4.03'], ['G-1', '5703', 'SPMS', 'Karen Lee', 'Female', '4.12'], ['G-1', '2353', 'SBS', 'Karen Wong', 'Female', '3.95'], ['G-1', '2069', 'SSS', 'Kathy Lau', 'Female', '4.48'], ['G-1', '3861', 'ASE', 'Layla Torres', 'Female', '4.52'], ['G-1', '162', 'SSS', 'Lila Patel', 'Female', '4.07'], ['G-1', '588', 'MAE', 'Lucas Walker', 'Male', '4.06'], ['G-1', '659', 'SSS', 'Maria Ivanovna', 'Female', '4.2'], ['G-1', '4820', 'CoE', 'Meera Singh', 'Female', '4.22'], ['G-1', '2151', 'EEE', 'Mei Hong', 'Female', '4.02'], ['G-1', '235', 'CCDS', 'Ming Zhang', 'Male', '4.06'], ['G-1', '527', 'EEE', 'Mohit Desai', 'Male', '4.06'], ['G-1', '1329', 'NIE', 'Nguyen Van Sam', 'Male', '3.85'], ['G-1', '5119', 'ADM', 'Nhung Vu', 'Female', '4.04'], ['G-1', '809', 'CoB (NBS)', 'Nisha Das', 'Female', '4.26'], ['G-1', '2650', 'SoH', 'Nurul Shafika', 'Female', '4.09'], ['G-1', '4657', 'SoH', 'Oleg Petrovich', 'Male', '4'], ['G-1', '2818', 'CoB (NBS)', 'Oliver Tan', 'Male', '4.09'], ['G-1', '3628', 'EEE', 'Omer Ahmed', 'Male', '4.06'], ['G-1', '1555', 'MAE', 'Prerna Gupta', 'Female', '4.04'], ['G-1', '1271', 'SSS', 'Priya Singh', 'Female', '4.17'], ['G-1', '75', 'CCDS', 'Sakina Ahmed', 'Female', '4.03'], ['G-1', '4338', 'SPMS', 'Sana Jain', 'Female', '4.22'], ['G-1', '71', 'SoH', 'Savannah Taylor', 'Female', '4.19'], ['G-1', '2776', 'CCEB', 'Siddharth Nair', 'Male', '4.14'], ['G-1', '2417', 'SSS', 'Truong Minh Chau', 'Female', '3.88'], ['G-1', '5477', 'SoH', 'Vikram Desai', 'Male', '4.09'], ['G-1', '2326', 'CoB (NBS)', 'Vivi Dwi', 'Female', '3.95'], ['G-1', '3930', 'EEE', 'Xun Wei', 'Female', '4.18'], ['G-1', '1645', 'CoE', 'Zachary Wu', 'Male', '3.93'], ['G-1', '592', 'MSE', 'Zara Chang', 'Female', '4.11']]

# %%
# Cell 3: Count the number of students in a tutorial group and create a GPA dictionary
number_of_student = 0
# Count students in the tutorial group 'G-1'
for i in tut_dict['G-1']:
    number_of_student += 1
print("Number of students in G-1:", number_of_student)

# Create GPA dictionary with structure 'tutorial group': [[GPA, name, school, gender]]
gpa_dict = {}
for tut, tut_info in tut_dict.items():
    # Loop through each student in the tutorial group
    for i in range(number_of_student):
        student_info = tut_info[i]
        student_gpa = float(student_info[5])  # Convert GPA to float
        student_name = student_info[3]
        student_school = student_info[2]
        student_gender = student_info[4]
        student_id=student_info[1]

        # Add the student's GPA, name, school, student_id and gender to the dictionary
        if tut not in gpa_dict:
            gpa_dict[tut] = [[student_gpa, student_name, student_school, student_gender, student_id]]
        else:
            gpa_dict[tut].append([student_gpa, student_name, student_school, student_gender, student_id])

# Print GPA data to check structure and contents
print("GPA Data for Group G-1:", gpa_dict['G-1'])
print(len(gpa_dict['G-1']))
# Out:
# Number of students in G-1: 50
# GPA Data for Group G-1: [[4.02, 'Aarav Singh', 'CCDS', 'Male', '5002'], [4.05, 'Aarti Nair', 'EEE', 'Female', '3838'], [4.2, 'Adlan Bin Rahman', 'EEE', 'Male', '2091'], [4.01, 'Ajay Verma', 'CoB (NBS)', 'Male', '288'], [4.11, 'Amelia Kim', 'CCDS', 'Female', '4479'], [4.2, 'Ananya Ramesh', 'SoH', 'Male', '5708'], [4.01, 'Anjali Patel', 'WKW SCI', 'Female', '4563'], [4.15, 'Anthony Liu', 'WKW SCI', 'Male', '3989'], [4.03, 'Anya Kumar', 'EEE', 'Female', '2115'], [4.19, 'Areeba Khan', 'CoB (NBS)', 'Female', '1383'], [4.12, 'Darren Lee', 'CoE', 'Male', '1417'], [4.08, 'Felix Yip', 'CoB (NBS)', 'Male', '1075'], [3.88, 'Gabriel Young', 'EEE', 'Male', '3148'], [4.08, 'Grace Turner', 'CCDS', 'Female', '4402'], [4.1, 'Han Li', 'MAE', 'Female', '945'], [4.18, 'Harlow Wang', 'CoB (NBS)', 'Female', '2230'], [4.11, 'Henry Foster', 'EEE', 'Male', '4520'], [4.03, 'Isabella Thompson', 'CoB (NBS)', 'Female', '567'], [4.12, 'Jett Morales', 'MAE', 'Male', '1841'], [4.03, 'Jie Zhang', 'EEE', 'Male', '4576'], [4.12, 'Karen Lee', 'SPMS', 'Female', '5703'], [3.95, 'Karen Wong', 'SBS', 'Female', '2353'], [4.48, 'Kathy Lau', 'SSS', 'Female', '2069'], [4.52, 'Layla Torres', 'ASE', 'Female', '3861'], [4.07, 'Lila Patel', 'SSS', 'Female', '162'], [4.06, 'Lucas Walker', 'MAE', 'Male', '588'], [4.2, 'Maria Ivanovna', 'SSS', 'Female', '659'], [4.22, 'Meera Singh', 'CoE', 'Female', '4820'], [4.02, 'Mei Hong', 'EEE', 'Female', '2151'], [4.06, 'Ming Zhang', 'CCDS', 'Male', '235'], [4.06, 'Mohit Desai', 'EEE', 'Male', '527'], [3.85, 'Nguyen Van Sam', 'NIE', 'Male', '1329'], [4.04, 'Nhung Vu', 'ADM', 'Female', '5119'], [4.26, 'Nisha Das', 'CoB (NBS)', 'Female', '809'], [4.09, 'Nurul Shafika', 'SoH', 'Female', '2650'], [4.0, 'Oleg Petrovich', 'SoH', 'Male', '4657'], [4.09, 'Oliver Tan', 'CoB (NBS)', 'Male', '2818'], [4.06, 'Omer Ahmed', 'EEE', 'Male', '3628'], [4.04, 'Prerna Gupta', 'MAE', 'Female', '1555'], [4.17, 'Priya Singh', 'SSS', 'Female', '1271'], [4.03, 'Sakina Ahmed', 'CCDS', 'Female', '75'], [4.22, 'Sana Jain', 'SPMS', 'Female', '4338'], [4.19, 'Savannah Taylor', 'SoH', 'Female', '71'], [4.14, 'Siddharth Nair', 'CCEB', 'Male', '2776'], [3.88, 'Truong Minh Chau', 'SSS', 'Female', '2417'], [4.09, 'Vikram Desai', 'SoH', 'Male', '5477'], [3.95, 'Vivi Dwi', 'CoB (NBS)', 'Female', '2326'], [4.18, 'Xun Wei', 'EEE', 'Female', '3930'], [3.93, 'Zachary Wu', 'CoE', 'Male', '1645'], [4.11, 'Zara Chang', 'MSE', 'Female', '592']]
# 50

# %%
# Cell 4: Sort the list of GPA in each tutorial group
for tut, gpa in gpa_dict.items():
    # Sort each group's list by GPA in ascending order
    gpa_dict[tut] = sorted(gpa, key=lambda x: x[0])

# Print sorted GPA data for a specific group to verify
print("Sorted GPA Data for Group G-1:", gpa_dict['G-1'])
# Out:
# Sorted GPA Data for Group G-1: [[3.85, 'Nguyen Van Sam', 'NIE', 'Male', '1329'], [3.88, 'Gabriel Young', 'EEE', 'Male', '3148'], [3.88, 'Truong Minh Chau', 'SSS', 'Female', '2417'], [3.93, 'Zachary Wu', 'CoE', 'Male', '1645'], [3.95, 'Karen Wong', 'SBS', 'Female', '2353'], [3.95, 'Vivi Dwi', 'CoB (NBS)', 'Female', '2326'], [4.0, 'Oleg Petrovich', 'SoH', 'Male', '4657'], [4.01, 'Ajay Verma', 'CoB (NBS)', 'Male', '288'], [4.01, 'Anjali Patel', 'WKW SCI', 'Female', '4563'], [4.02, 'Aarav Singh', 'CCDS', 'Male', '5002'], [4.02, 'Mei Hong', 'EEE', 'Female', '2151'], [4.03, 'Anya Kumar', 'EEE', 'Female', '2115'], [4.03, 'Isabella Thompson', 'CoB (NBS)', 'Female', '567'], [4.03, 'Jie Zhang', 'EEE', 'Male', '4576'], [4.03, 'Sakina Ahmed', 'CCDS', 'Female', '75'], [4.04, 'Nhung Vu', 'ADM', 'Female', '5119'], [4.04, 'Prerna Gupta', 'MAE', 'Female', '1555'], [4.05, 'Aarti Nair', 'EEE', 'Female', '3838'], [4.06, 'Lucas Walker', 'MAE', 'Male', '588'], [4.06, 'Ming Zhang', 'CCDS', 'Male', '235'], [4.06, 'Mohit Desai', 'EEE', 'Male', '527'], [4.06, 'Omer Ahmed', 'EEE', 'Male', '3628'], [4.07, 'Lila Patel', 'SSS', 'Female', '162'], [4.08, 'Felix Yip', 'CoB (NBS)', 'Male', '1075'], [4.08, 'Grace Turner', 'CCDS', 'Female', '4402'], [4.09, 'Nurul Shafika', 'SoH', 'Female', '2650'], [4.09, 'Oliver Tan', 'CoB (NBS)', 'Male', '2818'], [4.09, 'Vikram Desai', 'SoH', 'Male', '5477'], [4.1, 'Han Li', 'MAE', 'Female', '945'], [4.11, 'Amelia Kim', 'CCDS', 'Female', '4479'], [4.11, 'Henry Foster', 'EEE', 'Male', '4520'], [4.11, 'Zara Chang', 'MSE', 'Female', '592'], [4.12, 'Darren Lee', 'CoE', 'Male', '1417'], [4.12, 'Jett Morales', 'MAE', 'Male', '1841'], [4.12, 'Karen Lee', 'SPMS', 'Female', '5703'], [4.14, 'Siddharth Nair', 'CCEB', 'Male', '2776'], [4.15, 'Anthony Liu', 'WKW SCI', 'Male', '3989'], [4.17, 'Priya Singh', 'SSS', 'Female', '1271'], [4.18, 'Harlow Wang', 'CoB (NBS)', 'Female', '2230'], [4.18, 'Xun Wei', 'EEE', 'Female', '3930'], [4.19, 'Areeba Khan', 'CoB (NBS)', 'Female', '1383'], [4.19, 'Savannah Taylor', 'SoH', 'Female', '71'], [4.2, 'Adlan Bin Rahman', 'EEE', 'Male', '2091'], [4.2, 'Ananya Ramesh', 'SoH', 'Male', '5708'], [4.2, 'Maria Ivanovna', 'SSS', 'Female', '659'], [4.22, 'Meera Singh', 'CoE', 'Female', '4820'], [4.22, 'Sana Jain', 'SPMS', 'Female', '4338'], [4.26, 'Nisha Das', 'CoB (NBS)', 'Female', '809'], [4.48, 'Kathy Lau', 'SSS', 'Female', '2069'], [4.52, 'Layla Torres', 'ASE', 'Female', '3861']]

# %%
# Cell 5: Count gender distribution in tutorial groups
# Initialize counters for male and female students in G-1
gender_count1 = {'Male': 0, 'Female': 0}
for student in gpa_dict['G-1']:
    # Increment the counter based on student gender
    gender_count1[student[3]] += 1
print("Gender Count in Group G-1:", gender_count1)

# Repeat the process for tutorial group G-2
gender_count2 = {'Male': 0, 'Female': 0}
for student in gpa_dict['G-2']:
    gender_count2[student[3]] += 1
print("Gender Count in Group G-2:", gender_count2)
# Out:
# Gender Count in Group G-1: {'Male': 21, 'Female': 29}
# Gender Count in Group G-2: {'Male': 18, 'Female': 32}

# %% [markdown]
# ## Algorithm Planning and Design
#
# ### Solution Design
# The algorithm follows these main steps:
# 1. Data Loading and Sorting: Organize data by tutorial groups.
# 2. GPA Categorization: Divide students into above, average, and below GPA groups.
# 3. Initial Grouping: Use constraints to form balanced groups.
# 4. Secondary Sorting: Add ungrouped students to groups needing additional members.
# 5. Final sorting: Sorting with relaxed constraints.

# %% [markdown]
# ### Modular Design
# - **first_sorting**: Initial sorting based on GPA, gender, and school.
# - **add_leftover**: Manages leftover students that are not added into the reserved dictionary.
# - **second_sort**: Second balancing of group members.
# - **final_sort**: Final sorting of the group members.

# %% [markdown]
# ### Step 2: Grouping and Sorting by GPA and Gender
# *This section begins grouping students based on GPA and gender distribution constraints.

# %%
# Cell 6: 
# Create dictionaries to categorize students based on GPA for each tutorial group
above_average_dict = {}
average_dict = {}
below_average_dict = {}

# Split each group into segments based on GPA
for tut, gpa_list in gpa_dict.items():
    # Top 20 students are considered above average
    above_average_dict[tut] = gpa_list[30:50]
    # Middle 10 students are considered average
    average_dict[tut] = gpa_list[20:30]
    # Bottom 20 students are considered below average
    below_average_dict[tut] = gpa_list[0:20]

# Print the above-average list for a specific group to verify
print("Above Average for Group G-2:", above_average_dict['G-2'])
# Out:
# Above Average for Group G-2: [[4.12, 'Jasper Lim', 'SPMS', 'Male', '2473'], [4.12, 'Mei Zhao', 'SBS', 'Female', '2712'], [4.15, 'Izzat Bin Ibrahim', 'CEE', 'Male', '3533'], [4.15, 'Mira Lin', 'CoB (NBS)', 'Female', '5080'], [4.15, 'Sophia Koh', 'ADM', 'Female', '1455'], [4.16, 'Nadia Iqbal', 'CCEB', 'Female', '3636'], [4.17, 'Carter Moore', 'MSE', 'Male', '2788'], [4.17, 'Lana Turner', 'CoB (NBS)', 'Female', '229'], [4.17, 'Selena Tan', 'MAE', 'Female', '1428'], [4.18, 'Isaiah Turner', 'EEE', 'Male', '586'], [4.18, 'Patricia Wong', 'CCEB', 'Female', '5226'], [4.19, 'Eli Walker', 'WKW SCI', 'Male', '3527'], [4.19, 'Fatima Yusof', 'MAE', 'Female', '5996'], [4.19, 'Gisela Tan', 'EEE', 'Female', '3926'], [4.19, 'Lina Binti Ali', 'SBS', 'Female', '5371'], [4.2, 'Lara Li', 'CCEB', 'Female', '1726'], [4.2, 'Nathaniel Adams', 'EEE', 'Male', '4392'], [4.2, 'Zhengrong', 'CCDS', 'Male', '1877'], [4.22, 'Shalini Pillai', 'MSE', 'Female', '3615'], [4.22, 'Sofia Chandra', 'CCDS', 'Female', '3611']]

# %% [markdown]
# # Computational Thinking Concept for first sorting
# 1. Decomposition: I used multiple dictionaries such as student_selected, student_gender and student_school to keep track of quotas that I need to meet
#
# 2. Pattern Recognition:
# - As I was working through the problem, my initial plan was to sort the gpa first and sort the gender in a way that makes sure that each of them dont exceed three. However it later struck me that majority gender of a tutorial group will definitely be three while the minority gender will be two in an idealistic situation. Therefore instead of checking two genders to be less than or equal to two in the first sorting, I changed the constraints to checking the majority gender to be less than or equal to three while the minority gender to be less than or equal to two.
#
# 3. Abstraction:
# - The first check to find the target gender and non target gender helps to abstracts personal details and make the code simpler
#
# 4. Algorithmic thinking:
# - first constraint check is gpa
# - second constraint check is simultaneous checks for both school and gender
#
# 5. Evaluation:
# *Problem faced*
# - Students from reserved dictionary does not include all the students that are not added into the sorted dictionary in the first sorting, so I created a fill in function to add student from above_average, below_average and average dictionary.

# %%
# Cell 7: Define the first_sorting function
# This function will group students based on GPA, gender, and school constraints
def first_sorting(above_average, below_average, average, reserve_dict, sorted_dict, tut, group_number, female_count, male_count):
    group_size = 0
    student_selected = {'above': 0, 'below': 0, 'average': 0}
    student_gender = {'Male': 0, 'Female': 0}
    student_school = {}
    
    # Determine majority gender based on counts
    if male_count > female_count:
        target_gender = 'Male'
        non_target_gender = 'Female'
    else:
        target_gender = 'Female'
        non_target_gender = 'Male'



    # Loop to fill the group with 5 students based on certain criteria
    for i in range(5):
        # Select students from above, below, or average groups based on quotas
        curr_student = None
        if student_selected['above'] < 2 and above_average:
            curr_student = above_average.pop()
            curr_student.append('above')
        elif student_selected['below'] < 2 and below_average:
            curr_student = below_average.pop()
            curr_student.append('below')
        elif student_selected['average'] < 1 and average:
            curr_student = average.pop()
            curr_student.append('average')

        # If no student is selected, continue to the next loop iteration
        if not curr_student:
            continue

        # Retrieve student details for school and gender checks
        school = curr_student[2]
        gender = curr_student[3]

        # Ensure school and gender constraints are met; otherwise, add to reserved
        if student_school.get(school, 0) >= 2 or (gender == target_gender and student_gender[target_gender] >= 3) or (gender == non_target_gender and student_gender[non_target_gender] >= 2):
            reserve_dict[tut].append(curr_student)
            continue

        # If constraints are met, add student to sorted group
        sorted_dict[tut][group_number].append(curr_student)
        student_selected[curr_student[-1]] += 1
        student_gender[gender] += 1
        if curr_student[2] in student_school:
            student_school[school]+=1
        else:
            student_school[school]=1
        
    return student_selected, student_gender, student_school

# %%
# Cell 8: Define add_leftover function to add remaining students to reserved_dict
# Reason for some students to be left out, the first three checks are not executed, thus not all students are popped and not all are added into the reserved dictionary.

def add_leftover(above_average, below_average, average, reserved_dict, tut):
    # Add remaining above-average students to reserved with 'above' tag
    if above_average:
        for student in above_average:
            student.append('above')
        reserved_dict[tut].extend(above_average)

    # Add remaining below-average students to reserved with 'below' tag
    if below_average:
        for student in below_average:
            student.append('below')
        reserved_dict[tut].extend(below_average)

    # Add remaining average students to reserved with 'average' tag
    if average:
        for student in average:
            student.append('average')
        reserved_dict[tut].extend(average)
    
    return reserved_dict

# %%
# Cell 9: Initialize dictionaries for sorted, reserved, and count data
sorted_dict = {}
reserved_dict = {}
count_dict = {}

# Initialize empty lists for each tutorial group and group number
for key in tut_dict:
    sorted_dict[key] = {}
    reserved_dict[key] = []
    count_dict[key] = {}
    for i in range(1, 11):
        sorted_dict[key][i] = []
        count_dict[key][i] = []

print("Dictionaries initialized for sorting")
# Out:
# Dictionaries initialized for sorting

# %%
# Cell 10: Get gender counts for each tutorial group
gender_count_dict = {}
for key in tut_dict:
    gender_count_dict[key] = {'Male': 0, 'Female': 0}
    for student in gpa_dict[key]:
        # Count each gender for students in the group
        gender_count_dict[key][student[3]] += 1

print("Gender Count for Group G-2:", gender_count_dict['G-2'])
# Out:
# Gender Count for Group G-2: {'Male': 18, 'Female': 32}

# %%
# Cell 11: Run first sorting function and add leftover students to reserved_dict
for key in tut_dict:
    # Apply first_sorting to each group to organize students
    for i in range(1, 11):
        dictionary = first_sorting(above_average_dict[key], below_average_dict[key], average_dict[key], reserved_dict, sorted_dict, key, i, gender_count_dict[key]['Female'], gender_count_dict[key]['Male'])
        count_dict[key][i].append(dictionary)

# Add any leftover students from above, below, and average groups to reserved_dict
for key in tut_dict:    
    add_leftover(above_average_dict[key], below_average_dict[key], average_dict[key], reserved_dict, key)

print("Reserved Students for Group G-2:", len(reserved_dict['G-2']))
print(sorted_dict['G-2'])
# Out:
# Reserved Students for Group G-2: 7
# {1: [[4.22, 'Sofia Chandra', 'CCDS', 'Female', '3611', 'above'], [4.22, 'Shalini Pillai', 'MSE', 'Female', '3615', 'above'], [4.05, 'Derek Adams', 'SoH', 'Male', '3501', 'below'], [4.03, 'Yuri Chekhov', 'CCDS', 'Male', '1130', 'below']], 2: [[4.2, 'Zhengrong', 'CCDS', 'Male', '1877', 'above'], [4.2, 'Nathaniel Adams', 'EEE', 'Male', '4392', 'above'], [4.03, 'Yoshiko Mori', 'CCEB', 'Female', '3882', 'below'], [4.03, 'Xiu Li', 'CCEB', 'Female', '4759', 'below'], [4.11, 'Zain Qureshi', 'MSE', 'Female', '5994', 'average']], 3: [[4.2, 'Lara Li', 'CCEB', 'Female', '1726', 'above'], [4.19, 'Lina Binti Ali', 'SBS', 'Female', '5371', 'above'], [4.03, 'Winston Villanueva', 'SSS', 'Male', '248', 'below'], [4.03, 'Tina Tan', 'EEE', 'Female', '4624', 'below']], 4: [[4.19, 'Gisela Tan', 'EEE', 'Female', '3926', 'above'], [4.19, 'Fatima Yusof', 'MAE', 'Female', '5996', 'above'], [4.03, 'Tanya Sharma', 'ASE', 'Female', '3568', 'below'], [4.03, 'Ki-Hoon Kim', 'CCDS', 'Male', '5103', 'below']], 5: [[4.19, 'Eli Walker', 'WKW SCI', 'Male', '3527', 'above'], [4.18, 'Patricia Wong', 'CCEB', 'Female', '5226', 'above'], [4.03, 'Jesse Bennett', 'SSS', 'Male', '4453', 'below'], [4.03, 'Addison Chen', 'CEE', 'Female', '5802', 'below'], [4.09, 'Fatima Rani', 'SSS', 'Female', '4851', 'average']], 6: [[4.18, 'Isaiah Turner', 'EEE', 'Male', '586', 'above'], [4.17, 'Selena Tan', 'MAE', 'Female', '1428', 'above'], [4.02, 'Ahmad Ramlie', 'CEE', 'Male', '764', 'below'], [4.01, 'Lila Zhao', 'CCDS', 'Female', '2547', 'below']], 7: [[4.17, 'Lana Turner', 'CoB (NBS)', 'Female', '229', 'above'], [4.17, 'Carter Moore', 'MSE', 'Male', '2788', 'above'], [4.01, 'Anya Chua', 'SoH', 'Female', '321', 'below'], [4.01, 'Aadhya Sharma', 'CCDS', 'Female', '1765', 'below'], [4.07, 'Yang Zhang', 'CoB (NBS)', 'Male', '2611', 'average']], 8: [[4.16, 'Nadia Iqbal', 'CCEB', 'Female', '3636', 'above'], [4.15, 'Sophia Koh', 'ADM', 'Female', '1455', 'above'], [4.0, 'David Ho', 'NIE', 'Male', '3026', 'below'], [3.95, 'Haroon Ali', 'WKW SCI', 'Male', '3523', 'below'], [4.07, 'Priya Gupta', 'CoB (NBS)', 'Female', '3212', 'average']], 9: [[4.15, 'Mira Lin', 'CoB (NBS)', 'Female', '5080', 'above'], [4.15, 'Izzat Bin Ibrahim', 'CEE', 'Male', '3533', 'above'], [3.9, 'Chunhua', 'WKW SCI', 'Female', '5750', 'below'], [3.88, 'Stella Bryant', 'SBS', 'Female', '1965', 'below']], 10: [[4.12, 'Mei Zhao', 'SBS', 'Female', '2712', 'above'], [4.12, 'Jasper Lim', 'SPMS', 'Male', '2473', 'above'], [4.05, 'Mingjing', 'CCEB', 'Female', '1814', 'average']]}

# %%
# Cell 12: Verify sorted dictionary for Group G-2
# Print the final sorted dictionary to verify that students are organized by groups
print("Final Sorted Dictionary for Group G-2:", sorted_dict['G-2'])
# Out:
# Final Sorted Dictionary for Group G-2: {1: [[4.22, 'Sofia Chandra', 'CCDS', 'Female', '3611', 'above'], [4.22, 'Shalini Pillai', 'MSE', 'Female', '3615', 'above'], [4.05, 'Derek Adams', 'SoH', 'Male', '3501', 'below'], [4.03, 'Yuri Chekhov', 'CCDS', 'Male', '1130', 'below']], 2: [[4.2, 'Zhengrong', 'CCDS', 'Male', '1877', 'above'], [4.2, 'Nathaniel Adams', 'EEE', 'Male', '4392', 'above'], [4.03, 'Yoshiko Mori', 'CCEB', 'Female', '3882', 'below'], [4.03, 'Xiu Li', 'CCEB', 'Female', '4759', 'below'], [4.11, 'Zain Qureshi', 'MSE', 'Female', '5994', 'average']], 3: [[4.2, 'Lara Li', 'CCEB', 'Female', '1726', 'above'], [4.19, 'Lina Binti Ali', 'SBS', 'Female', '5371', 'above'], [4.03, 'Winston Villanueva', 'SSS', 'Male', '248', 'below'], [4.03, 'Tina Tan', 'EEE', 'Female', '4624', 'below']], 4: [[4.19, 'Gisela Tan', 'EEE', 'Female', '3926', 'above'], [4.19, 'Fatima Yusof', 'MAE', 'Female', '5996', 'above'], [4.03, 'Tanya Sharma', 'ASE', 'Female', '3568', 'below'], [4.03, 'Ki-Hoon Kim', 'CCDS', 'Male', '5103', 'below']], 5: [[4.19, 'Eli Walker', 'WKW SCI', 'Male', '3527', 'above'], [4.18, 'Patricia Wong', 'CCEB', 'Female', '5226', 'above'], [4.03, 'Jesse Bennett', 'SSS', 'Male', '4453', 'below'], [4.03, 'Addison Chen', 'CEE', 'Female', '5802', 'below'], [4.09, 'Fatima Rani', 'SSS', 'Female', '4851', 'average']], 6: [[4.18, 'Isaiah Turner', 'EEE', 'Male', '586', 'above'], [4.17, 'Selena Tan', 'MAE', 'Female', '1428', 'above'], [4.02, 'Ahmad Ramlie', 'CEE', 'Male', '764', 'below'], [4.01, 'Lila Zhao', 'CCDS', 'Female', '2547', 'below']], 7: [[4.17, 'Lana Turner', 'CoB (NBS)', 'Female', '229', 'above'], [4.17, 'Carter Moore', 'MSE', 'Male', '2788', 'above'], [4.01, 'Anya Chua', 'SoH', 'Female', '321', 'below'], [4.01, 'Aadhya Sharma', 'CCDS', 'Female', '1765', 'below'], [4.07, 'Yang Zhang', 'CoB (NBS)', 'Male', '2611', 'average']], 8: [[4.16, 'Nadia Iqbal', 'CCEB', 'Female', '3636', 'above'], [4.15, 'Sophia Koh', 'ADM', 'Female', '1455', 'above'], [4.0, 'David Ho', 'NIE', 'Male', '3026', 'below'], [3.95, 'Haroon Ali', 'WKW SCI', 'Male', '3523', 'below'], [4.07, 'Priya Gupta', 'CoB (NBS)', 'Female', '3212', 'average']], 9: [[4.15, 'Mira Lin', 'CoB (NBS)', 'Female', '5080', 'above'], [4.15, 'Izzat Bin Ibrahim', 'CEE', 'Male', '3533', 'above'], [3.9, 'Chunhua', 'WKW SCI', 'Female', '5750', 'below'], [3.88, 'Stella Bryant', 'SBS', 'Female', '1965', 'below']], 10: [[4.12, 'Mei Zhao', 'SBS', 'Female', '2712', 'above'], [4.12, 'Jasper Lim', 'SPMS', 'Male', '2473', 'above'], [4.05, 'Mingjing', 'CCEB', 'Female', '1814', 'average']]}

# %% [markdown]
# ### Evaluate the groupings from the first sorting:
# These are helper functions and functions that help to check whether the code is working.

# %%
# Cell 13: Determine the number of groups that need filling
# Helper function to identify groups with fewer than 5 students
def determine_group_filling(sorted_dict, tut_group):
    group = []
    for i in range(1, 11):
        if len(sorted_dict[tut_group][i]) < 5:
            group.append(i)  # Add groups that need filling
    return group      

# Determine groups with fewer males
def determine_group_with_less_male(group_filling, tut_group):
    group = []
    for i in group_filling:
        if count_dict[tut_group][i][0][1]["Male"] < count_dict[tut_group][i][0][1]['Female']:
            group.append(i)
    return group

# Determine groups with fewer females
def determine_group_with_less_female(group_filling, tut_group):
    group = []
    for i in group_filling:
        if count_dict[tut_group][i][0][1]["Male"] > count_dict[tut_group][i][0][1]['Female']:
            group.append(i)
    return group

# Get the number of males and females in the reserved dict
def number_of_males_females(reserved_dict, tut_group):
    male = 0
    female = 0
    for student in reserved_dict[tut_group]:
        if student[3] == 'Male':
            male += 1
        else:
            female += 1
    return male, female

# Identify groups with equal gender distribution
def determine_group_with_equal_gender(group_filling, group_with_less_male, group_with_less_female):
    group = []
    for i in group_filling:
        if i not in group_with_less_male and i not in group_with_less_female:
            group.append(i)
    return group

# %%
# Cell 14: Create a dictionary to track groups needing filling for each tutorial group
group_filling_dict = {}
for tut in tut_dict:
    group_filling_dict[tut] = []
    # Determine groups that need filling for each tut group
    group_filling_dict[tut].append(determine_group_filling(sorted_dict, tut))

print("Groups that need filling in G-2:", group_filling_dict.get('G-2'))
# Out:
# Groups that need filling in G-2: [[1, 3, 4, 6, 9, 10]]

# %% [markdown]
# ### Step 3: Secondary Sorting for Ungrouped Students
# Handles leftover students, ensuring all groups meet the required constraints

# %% [markdown]
# # Computational Thinking Concept for second sorting:
#
# Problem is that there are still leftovers unsorted after first sorting as the first sort only go through each students once for each of the 10 team:
# 1.	Decomposition: I broke the problem down into smaller problems:
# -	Finding and retrieving the names and details of the leftovers who were not sorted from the first sort
# -	Finding and retrieving the number of the leftovers by their category (E.g. GPA grp, Gender and school)
# -	Retrieving the teams that were not full
# -	Retrieving the sort criteria for each tut grp
# -	Validating and sorting students into the not full group
#
# 2.	Abstraction:
# -	As first sort already generated a dictionary of unsorted students, I can just use the dictionary “reserved dictionary”
# -	I can also get the number for each category for each team of each tutorial group from the dictionary “count_dict”
# -	Used a function “add_leftover” to add a simpler category ‘the GPA group’ into each student’s details
# -	Used a function “determine_group_filling” to get all the team that’s length is  less than 5 members for each tutorial group
# -	Used a for loop to go through each unfilled tutorial group in dictionary “group_filling”, which was retrieved from the function “determine_group_filling”
# -	Used a while loop to ensure that the program go through the list of unsorted student multiple times till the current team is full or if none of the students meet the criteria
# -	Used if statements to validate if the student meets the criteria of ‘If the unsorted student is a majority gender and the team has less than 3 majority gender’ or ‘If the unsorted student is a minority gender and the team has less than 2 minority gender’ AND if the team has less than 2 student from the same school as the unsorted student
# -	Used if statements to validate if for the student’s GPA group, if there is less than 2 above GPA group or below GPA group or less than 1 average GPA group in the team
#
# 3.	Pattern Recognition:
# - As I realised there is a pattern of getting the tutorial group and going through each student to check if they are valid to be in the list of unsort teams in the tutorial group, I implemented a for loop to iterate each tutorial group and another for loop to go through each student. I also implemented a while loop to go through the for loop of student until either the team is full or if none of the students fit the criteria.
#
# 4.	Algorithmic thinking:
#
# a.	In second sort, for each not full team that we retrieve from another function,
#
# b.	while the team are not full and leftovers is not empty
#
# c.	we get the details from the total leftover students for each tut grp, which are the no. of below avg, avg and above avg gpa, the total number for each gender and the number of leftover student’s school
#
# d.	then we get each student from the leftover dictionary
#
# e.	and see if it meets the criteria where either they are part of the majority gender and the team can still fit in another person of the majority gender or they are part of the minority gender and the team can still fit in another person of the minority gender
#
# f.	we also ensure that there is not another student in the team that is from the same school as the selected leftover student
#
# g.	lastly, we check if the student fall into one of the 3 gpa category and if the team can have them
#
# h.	if they dont fit either category, the for loop will move on to the next student until either one fits or none does, either way it will result in the while loop being broken
#
# i.	if the student meets all the category, the student and their details is added into the team and the for loop is broken, then the while loop is repeated to see if the current team is full,
#
# j.	if the current team is still not full, the code will repeat and get into another for loop and thus get another student till either the current team is full and the while loop is broken or all the students are unable to meet the current team’s requirements and the while loop is forced to break
#
# k.	afterwards, it moves on to the next team and the code repeats again
#
# l.	finally, some students are sorted in but there are still a few leftovers which the function will return
#
# 5.	Evaluation:
# There is still leftovers as they don’t fit the criteria due to having unsorted students due to every team having one student that is the same as the unsorted student’s school or if there is too much majority or minority gender to equally split between the 3:2 ratio for each team of every tutorial group

# %%
# Cell 15: Define the second sorting function to distribute reserved students into groups
def second_sort(reserved_dict, sorted_dict, count_dict, tut, group_filling, target_gender, non_target_gender):
    for group in group_filling:
        # Continue until each group has 5 students or reserved is empty
        while len(sorted_dict[tut][group]) < 5 and reserved_dict:
            # Retrieve counts for GPA, gender, and school
            count=count_dict[tut][group][0]
            gpa_count=count[0]
            gender_count=count[1]
            school_count=count[2]
            
            # Determine which gender to add based on the 3:2 gender requirement
            if gender_count[target_gender] < 3:
                required_gender = target_gender
            elif gender_count[non_target_gender] < 2:
                required_gender = non_target_gender

            # Search for a suitable student in the reserved dict
            student_added = False
            # Search for a suitable student in the reserved dict              
            for student in reserved_dict[tut]:
                school = student[2]
                gender = student[3]
                gpa_type = student[-1]

                # Check if student meets gender, school, and GPA constraints
                if gender == required_gender and school_count.get(school, 0) < 2:
                    if (gpa_type == 'above' and gpa_count['above'] < 2) or \
                       (gpa_type == 'below' and gpa_count['below'] < 2) or \
                       (gpa_type == 'average' and gpa_count['average'] < 1):

                        # Add student to the group

                        sorted_dict[tut][group].append(student)
                        reserved_dict[tut].remove(student)
                        
                        # Update counts
                        gender_count[gender] += 1
                        gpa_count[gpa_type] += 1
                        school_count[school] = school_count.get(school, 0) + 1
                        student_added = True
                        
                        break  # Stop searching once a suitable student is added
                    
                 
            
            # If no student was added, break to avoid an infinite loop
            if not student_added:
                break


    return reserved_dict

# %%
# Cell 16: Apply the second sorting function
for tut in tut_dict:
    # Determine target and non-target genders for sorting based on group balance
    if gender_count_dict[tut]['Male'] >= gender_count_dict[tut]['Female']:
        target_gender = 'Male'
        non_target_gender = 'Female'
    else:
        target_gender = 'Female'
        non_target_gender = 'Male'
        
    # Perform second sort using gender targets
    second_sort(reserved_dict, sorted_dict, count_dict, tut, group_filling_dict[tut][0], target_gender, non_target_gender)

# Verify final sorted dictionary for Group G-2 after second sort
print("Sorted dictionary for G-2 after second sort:", sorted_dict.get('G-2'))
# Out:
# Sorted dictionary for G-2 after second sort: {1: [[4.22, 'Sofia Chandra', 'CCDS', 'Female', '3611', 'above'], [4.22, 'Shalini Pillai', 'MSE', 'Female', '3615', 'above'], [4.05, 'Derek Adams', 'SoH', 'Male', '3501', 'below'], [4.03, 'Yuri Chekhov', 'CCDS', 'Male', '1130', 'below'], [4.06, 'Shirley Tan', 'MAE', 'Female', '4558', 'average']], 2: [[4.2, 'Zhengrong', 'CCDS', 'Male', '1877', 'above'], [4.2, 'Nathaniel Adams', 'EEE', 'Male', '4392', 'above'], [4.03, 'Yoshiko Mori', 'CCEB', 'Female', '3882', 'below'], [4.03, 'Xiu Li', 'CCEB', 'Female', '4759', 'below'], [4.11, 'Zain Qureshi', 'MSE', 'Female', '5994', 'average']], 3: [[4.2, 'Lara Li', 'CCEB', 'Female', '1726', 'above'], [4.19, 'Lina Binti Ali', 'SBS', 'Female', '5371', 'above'], [4.03, 'Winston Villanueva', 'SSS', 'Male', '248', 'below'], [4.03, 'Tina Tan', 'EEE', 'Female', '4624', 'below'], [4.12, 'Ali Abubakar', 'CEE', 'Male', '4006', 'average']], 4: [[4.19, 'Gisela Tan', 'EEE', 'Female', '3926', 'above'], [4.19, 'Fatima Yusof', 'MAE', 'Female', '5996', 'above'], [4.03, 'Tanya Sharma', 'ASE', 'Female', '3568', 'below'], [4.03, 'Ki-Hoon Kim', 'CCDS', 'Male', '5103', 'below']], 5: [[4.19, 'Eli Walker', 'WKW SCI', 'Male', '3527', 'above'], [4.18, 'Patricia Wong', 'CCEB', 'Female', '5226', 'above'], [4.03, 'Jesse Bennett', 'SSS', 'Male', '4453', 'below'], [4.03, 'Addison Chen', 'CEE', 'Female', '5802', 'below'], [4.09, 'Fatima Rani', 'SSS', 'Female', '4851', 'average']], 6: [[4.18, 'Isaiah Turner', 'EEE', 'Male', '586', 'above'], [4.17, 'Selena Tan', 'MAE', 'Female', '1428', 'above'], [4.02, 'Ahmad Ramlie', 'CEE', 'Male', '764', 'below'], [4.01, 'Lila Zhao', 'CCDS', 'Female', '2547', 'below'], [4.1, 'Brianna Johnson', 'CCDS', 'Female', '460', 'average']], 7: [[4.17, 'Lana Turner', 'CoB (NBS)', 'Female', '229', 'above'], [4.17, 'Carter Moore', 'MSE', 'Male', '2788', 'above'], [4.01, 'Anya Chua', 'SoH', 'Female', '321', 'below'], [4.01, 'Aadhya Sharma', 'CCDS', 'Female', '1765', 'below'], [4.07, 'Yang Zhang', 'CoB (NBS)', 'Male', '2611', 'average']], 8: [[4.16, 'Nadia Iqbal', 'CCEB', 'Female', '3636', 'above'], [4.15, 'Sophia Koh', 'ADM', 'Female', '1455', 'above'], [4.0, 'David Ho', 'NIE', 'Male', '3026', 'below'], [3.95, 'Haroon Ali', 'WKW SCI', 'Male', '3523', 'below'], [4.07, 'Priya Gupta', 'CoB (NBS)', 'Female', '3212', 'average']], 9: [[4.15, 'Mira Lin', 'CoB (NBS)', 'Female', '5080', 'above'], [4.15, 'Izzat Bin Ibrahim', 'CEE', 'Male', '3533', 'above'], [3.9, 'Chunhua', 'WKW SCI', 'Female', '5750', 'below'], [3.88, 'Stella Bryant', 'SBS', 'Female', '1965', 'below']], 10: [[4.12, 'Mei Zhao', 'SBS', 'Female', '2712', 'above'], [4.12, 'Jasper Lim', 'SPMS', 'Male', '2473', 'above'], [4.05, 'Mingjing', 'CCEB', 'Female', '1814', 'average'], [4.03, 'Nguyen Thi Phuong', 'NIE', 'Female', '4123', 'below'], [4.01, 'Quinn Lee', 'SoH', 'Male', '5073', 'below']]}

# %% [markdown]
# ### Evaluate groupings after second round of sorting:

# %%
# Cell 17: Print count dictionary for Group G-2 to verify student distribution
print("Count dictionary for G-2:", count_dict.get('G-2'))
# Out:
# Count dictionary for G-2: {1: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'CCDS': 2, 'MSE': 1, 'SoH': 1, 'MAE': 1})], 2: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'CCDS': 1, 'EEE': 1, 'CCEB': 2, 'MSE': 1})], 3: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'CCEB': 1, 'SBS': 1, 'SSS': 1, 'EEE': 1, 'CEE': 1})], 4: [({'above': 2, 'below': 2, 'average': 0}, {'Male': 1, 'Female': 3}, {'EEE': 1, 'MAE': 1, 'ASE': 1, 'CCDS': 1})], 5: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'WKW SCI': 1, 'CCEB': 1, 'SSS': 2, 'CEE': 1})], 6: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'EEE': 1, 'MAE': 1, 'CEE': 1, 'CCDS': 2})], 7: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'CoB (NBS)': 2, 'MSE': 1, 'SoH': 1, 'CCDS': 1})], 8: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'CCEB': 1, 'ADM': 1, 'NIE': 1, 'WKW SCI': 1, 'CoB (NBS)': 1})], 9: [({'above': 2, 'below': 2, 'average': 0}, {'Male': 1, 'Female': 3}, {'CoB (NBS)': 1, 'CEE': 1, 'WKW SCI': 1, 'SBS': 1})], 10: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'SBS': 1, 'SPMS': 1, 'CCEB': 1, 'NIE': 1, 'SoH': 1})]}

# %%
# Cell 18: Initialize final group filling based on current sorted dictionary
# This identifies any remaining groups with fewer than 5 students
second_group_filling = {}
for tut in tut_dict:
    second_group_filling[tut] = []
    second_group_filling[tut].append(determine_group_filling(sorted_dict, tut))

print("Second group filling needed for G-2:", second_group_filling.get('G-2'))
# Out:
# Second group filling needed for G-2: [[4, 9]]

# %% [markdown]
# # Computational Thinking Concept for final sorting
#
# 1. Decomposition:
# - Split the checks into smaller parts:
# - First check if the group still requires students (<5), then check if it requires any specific gender, then add student accordingly
#
#
# 2. Pattern Recognition:
# - Noticed that underfilled groups can still be filled according to the gender restriction despite not being able to be filled by the first and second sorting
#
# 3. Abstraction:
# - Abstracts the group information to just the number of people in the group and the gender ratio
# - Abstract the reserve students information to just their gender, ignoring all other details
#
# 4. Algorithmic thinking:
# - Identify undefilled groups
# - Check if they need a specific gender to fill
# - Fill accordingly from reserve_dict
# - Update reserve_dict
# - Repeat until all groups are filled
#
# 5. Evaluation:
# - Issue arises if a group needs a specific gender, but the reserve_dict no longer has students of that gender leading to compromised gender ratio
# - But since we prioritise group completion over restrictions in the final sorting, its a compromise we accept.

# %%
# Cell 19: Final sorting to ensure gender distribution requirements are met
def final_sort(final_group_filling, sorted_dict, reserved_dict, count_dict, tut):
    # Ensure gender constraints are met for each group needing final sorting
    for group in final_group_filling:
        while len(sorted_dict[tut][group])<5:
            count=count_dict[tut][group][0]
            gpa_count=count[0]
            gender_count=count[1]
            school_count=count[2]
            students_to_remove=[]

            for student in reserved_dict[tut]:
                school = student[2]
                gender = student[3]
                gpa_type = student[-1]

                # Add male if male count is less than female
                if gender_count['Male']<=gender_count['Female']:
                    if gender=='Male':
                        
                        sorted_dict[tut][group].append(student)
                        students_to_remove.append(student)
                        
                        gender_count[gender] += 1
                        gpa_count[gpa_type] += 1
                        school_count[school] = school_count.get(school, 0) + 1
                        break
                        
                # Add female if female count is less than male                       
                elif gender_count['Female']<=gender_count['Male']:
                    if gender=='Female':
                        
                        sorted_dict[tut][group].append(student)
                        students_to_remove.append(student)
                        
                        gender_count[gender] += 1
                        gpa_count[gpa_type] += 1
                        school_count[school] = school_count.get(school, 0) + 1
                        break
            # Remove students added to the sorted group from the reserved list            
            for student in students_to_remove:
                reserved_dict[tut].remove(student)
                    
            
            # If no suitable students, add remaining from reserved
            if not students_to_remove and reserved_dict[tut]:
                while len(sorted_dict[tut][group]) < 5 and reserved_dict[tut]:
                    student=reserved_dict[tut][0]
                    school = student[2]
                    gender = student[3]
                    gpa_type = student[-1]
                    sorted_dict[tut][group].append(student)
                    reserved_dict[tut].remove(student)

                    gender_count[gender] += 1
                    gpa_count[gpa_type] += 1
                    school_count[school] = school_count.get(school, 0) + 1
                
                break

# %%
# Cell 20: Apply final sorting
for tut in tut_dict:
    final_sort(second_group_filling[tut][0], sorted_dict, reserved_dict, count_dict, tut)

# %%
# Cell 21: Print count dictionary for Group G-1 after final sorting
print("Count dictionary for G-1 after final sorting:", count_dict.get('G-1'))
# Out:
# Count dictionary for G-1 after final sorting: {1: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'ASE': 1, 'SSS': 1, 'CCDS': 2, 'MAE': 1})], 2: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'CoB (NBS)': 1, 'SPMS': 1, 'EEE': 2, 'SoH': 1})], 3: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'CoE': 1, 'SSS': 1, 'CCDS': 1, 'EEE': 1, 'CoB (NBS)': 1})], 4: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'SoH': 1, 'EEE': 2, 'CoB (NBS)': 1, 'MAE': 1})], 5: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'SoH': 1, 'CoB (NBS)': 2, 'EEE': 1, 'CCDS': 1})], 6: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'EEE': 2, 'CoB (NBS)': 2, 'WKW SCI': 1})], 7: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'SSS': 1, 'WKW SCI': 1, 'SoH': 1, 'CoB (NBS)': 1, 'CCDS': 1})], 8: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'CCEB': 1, 'SPMS': 1, 'SBS': 1, 'CoE': 1, 'SoH': 1})], 9: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 3, 'Female': 2}, {'MAE': 2, 'CoE': 1, 'SSS': 1, 'EEE': 1})], 10: [({'above': 2, 'below': 2, 'average': 1}, {'Male': 2, 'Female': 3}, {'MSE': 1, 'EEE': 1, 'SSS': 1, 'ADM': 1, 'NIE': 1})]}

# %%
# Cell 22: Print any remaining reserved students who could not be assigned
for tut in tut_dict:
    if reserved_dict[tut]:
        print(f"Reserved students in {tut}:", reserved_dict[tut])

# %%
# Cell 23: Print sorted dictionary for Group G-1 to verify final grouping
print("Final sorted dictionary for G-1:", sorted_dict.get('G-1'))
# Out:
# Final sorted dictionary for G-1: {1: [[4.52, 'Layla Torres', 'ASE', 'Female', '3861', 'above'], [4.48, 'Kathy Lau', 'SSS', 'Female', '2069', 'above'], [4.06, 'Ming Zhang', 'CCDS', 'Male', '235', 'below'], [4.06, 'Lucas Walker', 'MAE', 'Male', '588', 'below'], [4.11, 'Amelia Kim', 'CCDS', 'Female', '4479', 'average']], 2: [[4.26, 'Nisha Das', 'CoB (NBS)', 'Female', '809', 'above'], [4.22, 'Sana Jain', 'SPMS', 'Female', '4338', 'above'], [4.05, 'Aarti Nair', 'EEE', 'Female', '3838', 'below'], [4.09, 'Vikram Desai', 'SoH', 'Male', '5477', 'average'], [3.88, 'Gabriel Young', 'EEE', 'Male', '3148', 'below']], 3: [[4.22, 'Meera Singh', 'CoE', 'Female', '4820', 'above'], [4.2, 'Maria Ivanovna', 'SSS', 'Female', '659', 'above'], [4.03, 'Sakina Ahmed', 'CCDS', 'Female', '75', 'below'], [4.03, 'Jie Zhang', 'EEE', 'Male', '4576', 'below'], [4.08, 'Felix Yip', 'CoB (NBS)', 'Male', '1075', 'average']], 4: [[4.2, 'Ananya Ramesh', 'SoH', 'Male', '5708', 'above'], [4.2, 'Adlan Bin Rahman', 'EEE', 'Male', '2091', 'above'], [4.03, 'Isabella Thompson', 'CoB (NBS)', 'Female', '567', 'below'], [4.03, 'Anya Kumar', 'EEE', 'Female', '2115', 'below'], [4.1, 'Han Li', 'MAE', 'Female', '945', 'average']], 5: [[4.19, 'Savannah Taylor', 'SoH', 'Female', '71', 'above'], [4.19, 'Areeba Khan', 'CoB (NBS)', 'Female', '1383', 'above'], [4.02, 'Mei Hong', 'EEE', 'Female', '2151', 'below'], [4.02, 'Aarav Singh', 'CCDS', 'Male', '5002', 'below'], [4.09, 'Oliver Tan', 'CoB (NBS)', 'Male', '2818', 'average']], 6: [[4.18, 'Xun Wei', 'EEE', 'Female', '3930', 'above'], [4.18, 'Harlow Wang', 'CoB (NBS)', 'Female', '2230', 'above'], [4.01, 'Anjali Patel', 'WKW SCI', 'Female', '4563', 'below'], [4.01, 'Ajay Verma', 'CoB (NBS)', 'Male', '288', 'below'], [4.06, 'Mohit Desai', 'EEE', 'Male', '527', 'average']], 7: [[4.17, 'Priya Singh', 'SSS', 'Female', '1271', 'above'], [4.15, 'Anthony Liu', 'WKW SCI', 'Male', '3989', 'above'], [4.0, 'Oleg Petrovich', 'SoH', 'Male', '4657', 'below'], [3.95, 'Vivi Dwi', 'CoB (NBS)', 'Female', '2326', 'below'], [4.08, 'Grace Turner', 'CCDS', 'Female', '4402', 'average']], 8: [[4.14, 'Siddharth Nair', 'CCEB', 'Male', '2776', 'above'], [4.12, 'Karen Lee', 'SPMS', 'Female', '5703', 'above'], [3.95, 'Karen Wong', 'SBS', 'Female', '2353', 'below'], [3.93, 'Zachary Wu', 'CoE', 'Male', '1645', 'below'], [4.09, 'Nurul Shafika', 'SoH', 'Female', '2650', 'average']], 9: [[4.12, 'Jett Morales', 'MAE', 'Male', '1841', 'above'], [4.12, 'Darren Lee', 'CoE', 'Male', '1417', 'above'], [3.88, 'Truong Minh Chau', 'SSS', 'Female', '2417', 'below'], [4.04, 'Prerna Gupta', 'MAE', 'Female', '1555', 'below'], [4.06, 'Omer Ahmed', 'EEE', 'Male', '3628', 'average']], 10: [[4.11, 'Zara Chang', 'MSE', 'Female', '592', 'above'], [4.11, 'Henry Foster', 'EEE', 'Male', '4520', 'above'], [4.07, 'Lila Patel', 'SSS', 'Female', '162', 'average'], [4.04, 'Nhung Vu', 'ADM', 'Female', '5119', 'below'], [3.85, 'Nguyen Van Sam', 'NIE', 'Male', '1329', 'below']]}

# %%
# Cell 24: Assign each student their group number based on sorting results
for student in csvlist:
    tut = student[0]
    student_id = student[1]
    # Skip header
    if tut == 'Tutorial Group':
        continue
    # Assign group number to the student
    for group_number, group in sorted_dict[tut].items():
        for s in group:
            if student_id == s[4]:
                student.append(group_number)
                break

# Print the final csvlist with group numbers assigned to each student
print("CSV list with group numbers assigned:", csvlist)
# Out:
# CSV list with group numbers assigned: [['Tutorial Group', 'Student ID', 'School', 'Name', 'Gender', 'CGPA'], ['G-1', '5002', 'CCDS', 'Aarav Singh', 'Male', '4.02', 5], ['G-1', '3838', 'EEE', 'Aarti Nair', 'Female', '4.05', 2], ['G-1', '2091', 'EEE', 'Adlan Bin Rahman', 'Male', '4.2', 4], ['G-1', '288', 'CoB (NBS)', 'Ajay Verma', 'Male', '4.01', 6], ['G-1', '4479', 'CCDS', 'Amelia Kim', 'Female', '4.11', 1], ['G-1', '5708', 'SoH', 'Ananya Ramesh', 'Male', '4.2', 4], ['G-1', '4563', 'WKW SCI', 'Anjali Patel', 'Female', '4.01', 6], ['G-1', '3989', 'WKW SCI', 'Anthony Liu', 'Male', '4.15', 7], ['G-1', '2115', 'EEE', 'Anya Kumar', 'Female', '4.03', 4], ['G-1', '1383', 'CoB (NBS)', 'Areeba Khan', 'Female', '4.19', 5], ['G-1', '1417', 'CoE', 'Darren Lee', 'Male', '4.12', 9], ['G-1', '1075', 'CoB (NBS)', 'Felix Yip', 'Male', '4.08', 3], ['G-1', '3148', 'EEE', 'Gabriel Young', 'Male', '3.88', 2], ['G-1', '4402', 'CCDS', 'Grace Turner', 'Female', '4.08', 7], ['G-1', '945', 'MAE', 'Han Li', 'Female', '4.1', 4], ['G-1', '2230', 'CoB (NBS)', 'Harlow Wang', 'Female', '4.18', 6], ['G-1', '4520', 'EEE', 'Henry Foster', 'Male', '4.11', 10], ['G-1', '567', 'CoB (NBS)', 'Isabella Thompson', 'Female', '4.03', 4], ['G-1', '1841', 'MAE', 'Jett Morales', 'Male', '4.12', 9], ['G-1', '4576', 'EEE', 'Jie Zhang', 'Male', '4.03', 3], ['G-1', '5703', 'SPMS', 'Karen Lee', 'Female', '4.12', 8], ['G-1', '2353', 'SBS', 'Karen Wong', 'Female', '3.95', 8], ['G-1', '2069', 'SSS', 'Kathy Lau', 'Female', '4.48', 1], ['G-1', '3861', 'ASE', 'Layla Torres', 'Female', '4.52', 1], ['G-1', '162', 'SSS', 'Lila Patel', 'Female', '4.07', 10], ['G-1', '588', 'MAE', 'Lucas Walker', 'Male', '4.06', 1], ['G-1', '659', 'SSS', 'Maria Ivanovna', 'Female', '4.2', 3], ['G-1', '4820', 'CoE', 'Meera Singh', 'Female', '4.22', 3], ['G-1', '2151', 'EEE', 'Mei Hong', 'Female', '4.02', 5], ['G-1', '235', 'CCDS', 'Ming Zhang', 'Male', '4.06', 1], ['G-1', '527', 'EEE', 'Mohit Desai', 'Male', '4.06', 6], ['G-1', '1329', 'NIE', 'Nguyen Van Sam', 'Male', '3.85', 10], ['G-1', '5119', 'ADM', 'Nhung Vu', 'Female', '4.04', 10], ['G-1', '809', 'CoB (NBS)', 'Nisha Das', 'Female', '4.26', 2], ['G-1', '2650', 'SoH', 'Nurul Shafika', 'Female', '4.09', 8], ['G-1', '4657', 'SoH', 'Oleg Petrovich', 'Male', '4', 7], ['G-1', '2818', 'CoB (NBS)', 'Oliver Tan', 'Male', '4.09', 5], ['G-1', '3628', 'EEE', 'Omer Ahmed', 'Male', '4.06', 9], ['G-1', '1555', 'MAE', 'Prerna Gupta', 'Female', '4.04', 9], ['G-1', '1271', 'SSS', 'Priya Singh', 'Female', '4.17', 7], ['G-1', '75', 'CCDS', 'Sakina Ahmed', 'Female', '4.03', 3], ['G-1', '4338', 'SPMS', 'Sana Jain', 'Female', '4.22', 2], ['G-1', '71', 'SoH', 'Savannah Taylor', 'Female', '4.19', 5], ['G-1', '2776', 'CCEB', 'Siddharth Nair', 'Male', '4.14', 8], ['G-1', '2417', 'SSS', 'Truong Minh Chau', 'Female', '3.88', 9], ['G-1', '5477', 'SoH', 'Vikram Desai', 'Male', '4.09', 2], ['G-1', '2326', 'CoB (NBS)', 'Vivi Dwi', 'Female', '3.95', 7], ['G-1', '3930', 'EEE', 'Xun Wei', 'Female', '4.18', 6], ['G-1', '1645', 'CoE', 'Zachary Wu', 'Male', '3.93', 8], ['G-1', '592', 'MSE', 'Zara Chang', 'Female', '4.11', 10], ['G-10', '3329', 'MAE', 'Adrian Castillo', 'Male', '4.07', 1], ['G-10', '2581', 'ASE', 'Alyssa Green', 'Female', '3.94', 9], ['G-10', '594', 'MAE', 'Ananya Singh', 'Female', '4.2', 6], ['G-10', '560', 'SoH', 'Ayesha Javed', 'Female', '4.09', 10], ['G-10', '3841', 'SBS', 'Benjamin Turner', 'Male', '4.06', 4], ['G-10', '5624', 'EEE', 'Cheng Zhang', 'Male', '4.11', 4], ['G-10', '3794', 'CoB (NBS)', 'Christopher Miller', 'Male', '4.17', 9], ['G-10', '2253', 'EEE', 'Dante Wu', 'Male', '4.18', 8], ['G-10', '298', 'MAE', 'Freya Chen', 'Female', '4.09', 10], ['G-10', '403', 'SoH', 'Hae-Jin Lee', 'Female', '4.52', 1], ['G-10', '5734', 'MAE', 'Hassan Malik', 'Male', '4.03', 6], ['G-10', '611', 'SPMS', 'Hendra Mulyana', 'Male', '4.1', 7], ['G-10', '3051', 'LKCMedicine', 'Hunter Wilson', 'Male', '4.06', 3], ['G-10', '565', 'SoH', 'Isaiah Scott', 'Male', '4.15', 10], ['G-10', '223 ...

# %% [markdown]
# Phase 3: Output
#
# Save Results to CSV
# - Export the final team assignments into a new CSV file.

# %%
# Cell 25: Export the final sorted data to a new CSV file
csv_file = 'FCSF_Team2_JesmondTaySoonXiang.csv'  # File name for the output CSV
headers = ['Tutorial Group', 'Student ID', 'School', 'Name', 'Gender', 'GPA', 'Team Assigned']  # CSV headers

# Open the file in write mode and create a CSV writer
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    # Write headers to the CSV file
    writer.writerow(headers)
    
    # Write each student's data to the CSV file, starting from the second row (exclude header)
    writer.writerows(csvlist[1:])

# Confirmation message after writing the file
print("Grouped student data written to 'Grouped_student.csv'")
# Out:
# Grouped student data written to 'Grouped_student.csv'

# %% [markdown]
# ## Evaluation of the Algorithm
#
# ### Results Verification
# To confirm the algorithm's effectiveness:
# - **Student Count**: Verify each group contains a maximum of 5 students.
# - **Gender Balance**: Confirm the gender ratio in each group. 64 out of 1200 groups are created contain a 1:4 ratio, only 5.3%. Only 2 groups with 5:0 ratio, which is negligible.
# - **CSV Export**: Ensure the final grouped data is saved to `Grouped_student.csv`.
#
# Below is the count of students in each group, along with any remaining students who couldn’t be assigned:

# %%
# Display the number of boys and girls and total number os students in each group.

print("\nGender Distribution in Each Group:")
for tut_group, groups in sorted_dict.items():
    print(f"\nTutorial Group '{tut_group}':")
    for group_number, students in groups.items():
        # Initialize counters for male and female students
        male_count = sum(1 for student in students if student[3] == 'Male')
        female_count = sum(1 for student in students if student[3] == 'Female')

        # Display the counts 
        print(f"  Group {group_number} - Males: {male_count}, Females: {female_count}")
        print(f"  Group {group_number} has {len(students)} students.")

    
# Check if reserved_dict contains unassigned students

print("\nUnassigned Students:")
for tut_group, unassigned_students in reserved_dict.items():
    if unassigned_students:  # Only print if there are unassigned students
        print(f"\nTutorial Group '{tut_group}' has {len(unassigned_students)} unassigned students:")
        for student in unassigned_students:
            print(f"  - {student}")
# Out:
# Gender Distribution in Each Group:
#
# Tutorial Group 'G-1':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-10':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-100':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-101':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-102':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-103':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 4, Females: 1
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-104':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-105':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 5, Females: 0
#   Group 10 has 5 students.
#
# Tutorial Group 'G-106':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 4, Females: 1
#   Group 10 has 5 students.
#
# Tutorial Group 'G-107':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-108':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 1, Females: 4
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-109':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-11':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 4, Females: 1
#   Group 10 has 5 students.
#
# Tutorial Group 'G-110':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-111':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-112':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-113':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 4, Females: 1
#   Group 10 has 5 students.
#
# Tutorial Group 'G-114':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 1, Females: 4
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 1, Females: 4
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-115':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 4, Females: 1
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-116':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-117':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-118':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-119':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 4, Females: 1
#   Group 10 has 5 students.
#
# Tutorial Group 'G-12':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-120':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-13':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-14':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-15':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-16':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 4, Females: 1
#   Group 10 has 5 students.
#
# Tutorial Group 'G-17':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 1, Females: 4
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-18':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 1, Females: 4
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-19':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-2':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 1, Females: 4
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 1, Females: 4
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-20':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-21':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-22':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-23':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-24':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-25':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 1, Females: 4
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-26':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 1, Females: 4
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-27':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-28':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 4, Females: 1
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-29':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 1, Females: 4
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-3':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 1, Females: 4
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-30':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-31':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 1, Females: 4
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-32':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 4, Females: 1
#   Group 9 has 5 students.
#   Group 10 - Males: 4, Females: 1
#   Group 10 has 5 students.
#
# Tutorial Group 'G-33':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-34':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 4, Females: 1
#   Group 10 has 5 students.
#
# Tutorial Group 'G-35':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-36':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-37':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-38':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-39':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 1, Females: 4
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-4':
#   Group 1 - Males: 1, Females: 4
#   Group 1 has 5 students.
#   Group 2 - Males: 1, Females: 4
#   Group 2 has 5 students.
#   Group 3 - Males: 1, Females: 4
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 1, Females: 4
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-40':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 4, Females: 1
#   Group 10 has 5 students.
#
# Tutorial Group 'G-41':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 4, Females: 1
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-42':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 4, Females: 1
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-43':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-44':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-45':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 1, Females: 4
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-46':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 1, Females: 4
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-47':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 4, Females: 1
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-48':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-49':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-5':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 1, Females: 4
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 1, Females: 4
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-50':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-51':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-52':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-53':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-54':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-55':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-56':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 1, Females: 4
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-57':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-58':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-59':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-6':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-60':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
# ...
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-77':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-78':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-79':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-8':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 4, Females: 1
#   Group 10 has 5 students.
#
# Tutorial Group 'G-80':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-81':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-82':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-83':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-84':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-85':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-86':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-87':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-88':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-89':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-9':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 4, Females: 1
#   Group 10 has 5 students.
#
# Tutorial Group 'G-90':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-91':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-92':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-93':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-94':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 1, Females: 4
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 1, Females: 4
#   Group 10 has 5 students.
#
# Tutorial Group 'G-95':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-96':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 2, Females: 3
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 3, Females: 2
#   Group 10 has 5 students.
#
# Tutorial Group 'G-97':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 1, Females: 4
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 1, Females: 4
#   Group 9 has 5 students.
#   Group 10 - Males: 0, Females: 5
#   Group 10 has 5 students.
#
# Tutorial Group 'G-98':
#   Group 1 - Males: 3, Females: 2
#   Group 1 has 5 students.
#   Group 2 - Males: 3, Females: 2
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 3, Females: 2
#   Group 4 has 5 students.
#   Group 5 - Males: 3, Females: 2
#   Group 5 has 5 students.
#   Group 6 - Males: 3, Females: 2
#   Group 6 has 5 students.
#   Group 7 - Males: 3, Females: 2
#   Group 7 has 5 students.
#   Group 8 - Males: 3, Females: 2
#   Group 8 has 5 students.
#   Group 9 - Males: 3, Females: 2
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Tutorial Group 'G-99':
#   Group 1 - Males: 2, Females: 3
#   Group 1 has 5 students.
#   Group 2 - Males: 2, Females: 3
#   Group 2 has 5 students.
#   Group 3 - Males: 3, Females: 2
#   Group 3 has 5 students.
#   Group 4 - Males: 2, Females: 3
#   Group 4 has 5 students.
#   Group 5 - Males: 2, Females: 3
#   Group 5 has 5 students.
#   Group 6 - Males: 2, Females: 3
#   Group 6 has 5 students.
#   Group 7 - Males: 2, Females: 3
#   Group 7 has 5 students.
#   Group 8 - Males: 2, Females: 3
#   Group 8 has 5 students.
#   Group 9 - Males: 2, Females: 3
#   Group 9 has 5 students.
#   Group 10 - Males: 2, Females: 3
#   Group 10 has 5 students.
#
# Unassigned Students:

# %%
# Display groups with a 1:4 gender ratio

print("Groups with a 1:4 gender ratio:")
found = False  # Flag to check if any group meets the condition
number=0
for tut_group, groups in sorted_dict.items():
    for group_number, students in groups.items():
        # Count the number of males and females in the current group
        male_count = sum(1 for student in students if student[3] == 'Male')
        female_count = sum(1 for student in students if student[3] == 'Female')

        # Check for a 1:4 or 4:1 gender ratio
        if (male_count == 1 and female_count == 4) or (male_count == 4 and female_count == 1):
            print(f"\nTutorial Group '{tut_group}', Group {group_number}: Males = {male_count}, Females = {female_count}")
            number+=1
            for student in students:
                print(f"  - {student}")
            found = True  # Set flag to indicate at least one group was found

if not found:
    print("No groups with a 1:4 gender ratio were found.")
print(number)
# Out:
# Groups with a 1:4 gender ratio:
#
# Tutorial Group 'G-10', Group 10: Males = 1, Females = 4
#   - [4.15, 'Isaiah Scott', 'SoH', 'Male', '565', 'above']
#   - [4.12, 'Ximena Fernandez', 'MSE', 'Female', '5121', 'above']
#   - [4.09, 'Freya Chen', 'MAE', 'Female', '298', 'average']
#   - [3.88, 'Soo-Young Kim', 'ASE', 'Female', '2405', 'below']
#   - [4.09, 'Ayesha Javed', 'SoH', 'Female', '560', 'average']
#
# Tutorial Group 'G-103', Group 6: Males = 4, Females = 1
#   - [4.19, 'Samantha Khan', 'CoB (NBS)', 'Female', '4821', 'above']
#   - [4.19, 'David Young', 'CoE', 'Male', '2165', 'above']
#   - [4.0, 'Irfan Bin Hassan', 'SPMS', 'Male', '4678', 'below']
#   - [4.03, 'Fahim Hussein', 'CCDS', 'Male', '2099', 'below']
#   - [4.09, 'Khalil Bin Ismail', 'SSS', 'Male', '2679', 'average']
#
# Tutorial Group 'G-106', Group 10: Males = 4, Females = 1
#   - [4.14, 'Hafiz Ahmad', 'WKW SCI', 'Male', '2147', 'above']
#   - [4.14, 'Eun-Hee Kim', 'NIE', 'Female', '1168', 'above']
#   - [4.08, 'Rahul Mehta', 'MAE', 'Male', '4783', 'average']
#   - [3.95, 'Gandhi Saputra', 'CCEB', 'Male', '3471', 'below']
#   - [4.05, 'Zedrick Ong', 'MAE', 'Male', '2370', 'average']
#
# Tutorial Group 'G-107', Group 10: Males = 1, Females = 4
#   - [4.12, 'Hayden Wu', 'CCDS', 'Female', '2877', 'above']
#   - [4.12, 'Archer Powell', 'NIE', 'Male', '1979', 'above']
#   - [4.04, 'Meera Gupta', 'EEE', 'Female', '2334', 'average']
#   - [4.03, 'Amara Siti', 'SSS', 'Female', '992', 'below']
#   - [4.02, 'Xiaoling Chen', 'EEE', 'Female', '2941', 'below']
#
# Tutorial Group 'G-108', Group 6: Males = 1, Females = 4
#   - [4.18, 'Hana Watanabe', 'EEE', 'Female', '2511', 'above']
#   - [4.18, 'Caleb Parker', 'CoB (NBS)', 'Male', '5153', 'above']
#   - [4.0, 'Camila Allen', 'ADM', 'Female', '3921', 'below']
#   - [3.95, 'Hina Waseem', 'CCDS', 'Female', '4574', 'below']
#   - [4.09, 'Nadya Zainal', 'MSE', 'Female', '1905', 'average']
#
# Tutorial Group 'G-11', Group 10: Males = 4, Females = 1
#   - [4.12, 'Ella Johnson', 'CoE', 'Female', '4128', 'above']
#   - [4.1, 'William Carter', 'EEE', 'Male', '1955', 'above']
#   - [4.05, 'Caleb Murphy', 'CCDS', 'Male', '5491', 'average']
#   - [4.0, 'Erqi', 'CCDS', 'Male', '639', 'below']
#   - [4.04, 'Sebastian Mitchell', 'CCDS', 'Male', '3869', 'average']
#
# Tutorial Group 'G-113', Group 10: Males = 4, Females = 1
#   - [4.1, 'Yusuf Bin Sulaiman', 'CCDS', 'Male', '3228', 'above']
#   - [4.09, 'Logan Green', 'CCEB', 'Male', '447', 'above']
#   - [4.05, 'Taojie', 'SoH', 'Female', '5843', 'average']
#   - [4.04, 'Farrell Mendoza', 'MAE', 'Male', '2114', 'below']
#   - [3.78, 'Bharat Menon', 'CCDS', 'Male', '5740', 'below']
#
# Tutorial Group 'G-114', Group 5: Males = 1, Females = 4
#   - [4.18, 'Ariana Richardson', 'CoB (NBS)', 'Female', '2519', 'above']
#   - [4.15, 'Sana Malik', 'CEE', 'Female', '2324', 'above']
#   - [4.02, 'Sophie Patel', 'CCEB', 'Female', '4687', 'below']
#   - [4.02, 'Rei Takahashi', 'CoE', 'Male', '4874', 'below']
#   - [3.85, 'Kira Foster', 'EEE', 'Female', '1493', 'below']
#
# Tutorial Group 'G-114', Group 8: Males = 1, Females = 4
#   - [4.14, 'Aubree King', 'NIE', 'Female', '3391', 'above']
#   - [4.14, 'Alia Zainal', 'ASE', 'Female', '5810', 'above']
#   - [3.94, 'Svetlana Petrovna', 'CCDS', 'Female', '4028', 'below']
#   - [4.03, 'Xander Morris', 'EEE', 'Male', '5926', 'below']
#   - [4.06, 'Abigail Lewis', 'CCEB', 'Female', '2907', 'average']
#
# Tutorial Group 'G-114', Group 10: Males = 1, Females = 4
#   - [4.1, 'Oki Andri', 'EEE', 'Male', '1191', 'above']
#   - [4.1, 'Lily Tan', 'CCDS', 'Female', '2640', 'above']
#   - [4.08, 'Cheng Zhang', 'CCDS', 'Female', '4546', 'average']
#   - [3.88, 'Mila Wang', 'WKW SCI', 'Female', '1837', 'below']
#   - [4.06, 'Rosa Tan', 'CCDS', 'Female', '4464', 'average']
#
# Tutorial Group 'G-115', Group 9: Males = 4, Females = 1
#   - [4.15, 'Ryan Edwards', 'CCDS', 'Male', '4946', 'above']
#   - [4.15, 'Mukesh Kumar', 'CoB (NBS)', 'Male', '2427', 'above']
#   - [4.11, 'Meghan Carter', 'CoB (NBS)', 'Female', '3556', 'average']
#   - [3.89, 'James Wright', 'CoE', 'Male', '5081', 'below']
#   - [4.1, 'Zhi Yi Lim', 'CEE', 'Male', '3626', 'average']
#
# Tutorial Group 'G-119', Group 10: Males = 4, Females = 1
#   - [4.15, 'Felix Wong', 'CoB (NBS)', 'Male', '1629', 'above']
#   - [4.14, 'Priya Reddy', 'SPMS', 'Female', '2378', 'above']
#   - [4.1, 'Liam Walker', 'WKW SCI', 'Male', '1289', 'average']
#   - [3.9, 'Cai Wei', 'CEE', 'Male', '2067', 'below']
#   - [3.85, 'Andrew Wong', 'NIE', 'Male', '541', 'below']
#
# Tutorial Group 'G-120', Group 10: Males = 1, Females = 4
#   - [4.14, 'Charlotte Alexander', 'CoB (NBS)', 'Female', '4882', 'above']
#   - [4.12, 'Janelle Huang', 'CoB (NBS)', 'Female', '3750', 'above']
#   - [4.08, 'Victor Andreyev', 'EEE', 'Male', '3229', 'average']
#   - [4.0, 'Tina Sun', 'MAE', 'Female', '1317', 'below']
#   - [4.0, 'Samantha Patel', 'EEE', 'Female', '4631', 'below']
#
# Tutorial Group 'G-16', Group 10: Males = 4, Females = 1
#   - [4.11, 'Henry Cheung', 'MAE', 'Male', '2569', 'above']
#   - [4.1, 'Tristan Lim', 'ASE', 'Male', '4750', 'above']
#   - [3.88, 'Sophia Davis', 'MAE', 'Female', '2307', 'below']
#   - [3.85, 'Nitin Kumar', 'SoH', 'Male', '4469', 'below']
#   - [4.05, 'Albert Yip', 'EEE', 'Male', '3975', 'average']
#
# Tutorial Group 'G-17', Group 8: Males = 1, Females = 4
#   - [4.15, 'George Wilson', 'EEE', 'Male', '1914', 'above']
#   - [4.14, 'Maya Johnson', 'CCDS', 'Female', '5875', 'above']
#   - [3.9, 'Aleksei Koval', 'SoH', 'Female', '411', 'below']
#   - [3.89, 'Yuna Tan', 'CoB (NBS)', 'Female', '3780', 'below']
#   - [4.02, 'Sofia Lee', 'SSS', 'Female', '4801', 'below']
#
# Tutorial Group 'G-18', Group 7: Males = 1, Females = 4
#   - [4.15, 'Xiu Zhang', 'MAE', 'Female', '877', 'above']
#   - [4.15, 'Mohan Rao', 'CoB (NBS)', 'Male', '4155', 'above']
#   - [3.9, 'Isabella Lee', 'CCDS', 'Female', '4549', 'below']
#   - [3.9, 'Citra Amara', 'MSE', 'Female', '37', 'below']
#   - [4.07, 'Megan Lim', 'CoB (NBS)', 'Female', '4003', 'average']
#
# Tutorial Group 'G-2', Group 4: Males = 1, Females = 4
#   - [4.19, 'Gisela Tan', 'EEE', 'Female', '3926', 'above']
#   - [4.19, 'Fatima Yusof', 'MAE', 'Female', '5996', 'above']
#   - [4.03, 'Tanya Sharma', 'ASE', 'Female', '3568', 'below']
#   - [4.03, 'Ki-Hoon Kim', 'CCDS', 'Male', '5103', 'below']
#   - [4.05, 'Hanafi Bin Mohd', 'SSS', 'Female', '4738', 'average']
#
# Tutorial Group 'G-2', Group 9: Males = 1, Females = 4
#   - [4.15, 'Mira Lin', 'CoB (NBS)', 'Female', '5080', 'above']
#   - [4.15, 'Izzat Bin Ibrahim', 'CEE', 'Male', '3533', 'above']
#   - [3.9, 'Chunhua', 'WKW SCI', 'Female', '5750', 'below']
#   - [3.88, 'Stella Bryant', 'SBS', 'Female', '1965', 'below']
#   - [4.05, 'Layla Collins', 'EEE', 'Female', '2052', 'average']
#
# Tutorial Group 'G-25', Group 7: Males = 1, Females = 4
#   - [4.15, 'Shafika Binti Mohd', 'SSS', 'Female', '5065', 'above']
#   - [4.15, 'Natsuki Sato', 'SPMS', 'Female', '3778', 'above']
#   - [3.93, 'Ronald Tan', 'CCDS', 'Male', '698', 'below']
#   - [3.92, 'Sahara Chen', 'SoH', 'Female', '4475', 'below']
#   - [4.1, 'Ananya Reddy', 'CEE', 'Female', '4277', 'average']
#
# Tutorial Group 'G-26', Group 9: Males = 1, Females = 4
#   - [4.14, 'Victor Black', 'WKW SCI', 'Male', '2155', 'above']
#   - [4.14, 'Hafsa Khan', 'CCEB', 'Female', '1260', 'above']
#   - [4.09, 'Diya Singh', 'CCDS', 'Female', '1045', 'average']
#   - [4.0, 'Miki Aizawa', 'SBS', 'Female', '5094', 'below']
#   - [3.9, 'Jasmine Yeo', 'EEE', 'Female', '3477', 'below']
#
# Tutorial Group 'G-26', Group 10: Males = 1, Females = 4
#   - [4.13, 'Vera Kuznetsova', 'LKCMedicine', 'Female', '1817', 'above']
#   - [4.12, 'Elena Leonova', 'ADM', 'Female', '204', 'above']
#   - [4.06, 'Rishabh Sharma', 'CoE', 'Male', '3685', 'average']
#   - [3.9, 'Ruby Lee', 'CCEB', 'Female', '2691', 'below']
#   - [3.88, 'Deepa Menon', 'CoB (NBS)', 'Female', '3204', 'below']
#
# Tutorial Group 'G-28', Group 5: Males = 4, Females = 1
#   - [4.18, 'Mark Johnson', 'ASE', 'Male', '2738', 'above']
#   - [4.18, 'Lily Cook', 'SSS', 'Female', '2080', 'above']
#   - [4.01, 'Steve Lau', 'EEE', 'Male', '1320', 'below']
#   - [4.1, 'Arif Hussain', 'CoB (NBS)', 'Male', '3156', 'average']
#   - [3.9, 'Elijah Carter', 'CCEB', 'Male', '256', 'below']
#
# Tutorial Group 'G-29', Group 5: Males = 1, Females = 4
#   - [4.18, 'Kimberly Lim', 'CoE', 'Female', '202', 'above']
#   - [4.18, 'Ananya Sharma', 'CoB (NBS)', 'Female', '213', 'above']
#   - [4.0, 'Janelle Tan', 'SSS', 'Female', '4339', 'below']
#   - [3.96, 'Hao Xun', 'EEE', 'Male', '942', 'below']
#   - [4.06, 'Kelly Ng', 'WKW SCI', 'Female', '3347', 'average']
#
# Tutorial Group 'G-3', Group 8: Males = 1, Females = 4
#   - [4.15, 'Gita Saputra', 'WKW SCI', 'Female', '5379', 'above']
#   - [4.15, 'Asher Brown', 'CoE', 'Male', '4723', 'above']
#   - [3.9, 'Maya Zhang', 'CoB (NBS)', 'Female', '3612', 'below']
#   - [3.86, 'Neha Sharma', 'MAE', 'Female', '3569', 'below']
#   - [4.09, 'Riya Shah', 'CEE', 'Female', '1474', 'average']
#
# Tutorial Group 'G-31', Group 6: Males = 1, Females = 4
#   - [4.19, 'Moe Yamashita', 'EEE', 'Female', '169', 'above']
#   - [4.19, 'Mika Sato', 'EEE', 'Female', '236', 'above']
#   - [3.95, 'Toby Lim', 'MAE', 'Male', '2225', 'below']
#   - [3.92, 'Ella Gonzalez', 'CCEB', 'Female', '2431', 'below']
#   - [4.09, 'Chloe Torres', 'CoB (NBS)', 'Female', '365', 'average']
#
# Tutorial Group 'G-32', Group 9: Males = 4, Females = 1
#   - [4.14, 'Caleb Nelson', 'CEE', 'Male', '3610', 'above']
#   - [4.14, 'Anya Iyer', 'MAE', 'Female', '4841', 'above']
#   - [4.1, 'Anthony Stewart', 'EEE', 'Male', '2180', 'average']
#   - [4.03, 'Hao Chen', 'EEE', 'Male', '1919', 'below']
#   - [4.03, 'Colton Ross', 'CCEB', 'Male', '182', 'below']
#
# Tutorial Group 'G-32', Group 10: Males = 4, Females = 1
#   - [4.11, 'Yani Tan', 'LKCMedicine', 'Female', '2983', 'above']
#   - [4.11, 'Igor Petrov', 'CoE', 'Male', '4978', 'above']
#   - [4.09, 'Kien Vo', 'CEE', 'Male', '5143', 'average']
#   - [4.01, 'Sergey Fedorov', 'LKCMedicine', 'Male', '3716', 'below']
#   - [3.85, 'Xiaofang', 'CEE', 'Male', '2054', 'below']
#
# Tutorial Group 'G-34', Group 10: Males = 4, Females = 1
#   - [4.14, 'Owen Cox', 'SPMS', 'Male', '5564', 'above']
#   - [4.14, 'Li Qiang', 'CCEB', 'Male', '5851', 'above']
#   - [4.08, 'Lily Li', 'CoE', 'Female', '4010', 'average']
#   - [3.97, 'Xiao Liu', 'ASE', 'Male', '864', 'below']
#   - [3.97, 'Takashi Tanaka', 'SPMS', 'Male', '2153', 'below']
#
# Tutorial Group 'G-37', Group 10: Males = 1, Females = 4
#   - [4.14, 'Evelyn Carter', 'MAE', 'Female', '3606', 'above']
#   - [4.12, 'Bennett Yang', 'SPMS', 'Male', '374', 'above']
#   - [4.09, 'Kavya Joshi', 'CoB (NBS)', 'Female', '5879', 'average']
#   - [4.06, 'Ember Chen', 'CoB (NBS)', 'Female', '4217', 'below']
#   - [3.95, 'Nisha Binti', 'MAE', 'Female', '5799', 'below']
#
# Tutorial Group 'G-38', Group 10: Males = 1, Females = 4
#   - [4.15, 'Layla Price', 'ADM', 'Female', '3070', 'above']
#   - [4.14, 'Tanya Lim', 'CCDS', 'Female', '1805', 'above']
#   - [4.1, 'Aoqin', 'CoB (NBS)', 'Female', '3493', 'average']
#   - [3.87, 'Phan Duc Minh', 'MAE', 'Male', '4638', 'below']
#   - [3.91, 'Sana Rani', 'MAE', 'Female', '5285', 'below']
#
# Tutorial Group 'G-39', Group 9: Males = 1, Females = 4
#   - [4.12, 'Zara Chen', 'SSS', 'Female', '3657', 'above']
#   - [4.11, 'Nadia Wong', 'SSS', 'Female', '1070', 'above']
#   - [3.8, 'Xue Ling Tan', 'EEE', 'Female', '1853', 'below']
#   - [3.8, 'Mukti Bin Ibrahim', 'CoE', 'Male', '4185', 'below']
#   - [3.95, 'Layla Tsai', 'CoB (NBS)', 'Female', '60', 'below']
#
# Tutorial Group 'G-39', Group 10: Males = 1, Females = 4
#   - [4.11, 'Faye Wong', 'LKCMedicine', 'Female', '5823', 'above']
#   - [4.1, 'Shan Li', 'CCEB', 'Female', '1752', 'above']
#   - [4.08, 'Freddie Chan', 'SBS', 'Male', '687', 'average']
#   - [4.0, 'Bingli', 'CCDS', 'Female', '1487', 'below']
#   - [4.06, 'Elena Chen', 'MAE', 'Female', '977', 'average']
#
# Tutorial Group 'G-4', Group 1: Males = 1, Females = 4
#   - [4.26, 'Nozomi Takahashi', 'CoB (NBS)', 'Female', '1101', 'above']
#   - [4.22, 'Pooja Verma', 'MAE', 'Female', '3949', 'above']
#   - [4.05, 'Lan Huang', 'EEE', 'Female', '430', 'below']
#   - [4.0, 'Aiden Turner', 'CoB (NBS)', 'Male', '1619', 'below']
#   - [3.95, 'Dapeng', 'CCEB', 'Female', '3371', 'below']
#
# Tutorial Group 'G-4', Group 2: Males = 1, Females = 4
#   - [4.22, 'Gracie Scott', 'EEE', 'Female', '1930', 'above']
#   - [4.21, 'Fiona Yeo', 'WKW SCI', 'Female', '1830', 'above']
#   - [4.03, 'Emily Tan', 'CCDS', 'Female', '1991', 'below']
#   - [4.03, 'Emilio Garcia', 'CoE', 'Male', '5450', 'below']
#   - [4.08, 'Cathy Ng', 'MAE', 'Female', '2107', 'average']
#
# Tutorial Group 'G-4', Group 3: Males = 1, Females = 4
#   - [4.2, 'Nurul Hafiza', 'LKCMedicine', 'Female', '5413', 'above']
#   - [4.2, 'Eryan', 'CoB (NBS)', 'Female', '1162', 'above']
#   - [4.02, 'Sofia Khan', 'CoB (NBS)', 'Female', '1535', 'below']
#   - [4.02, 'Luca Wu', 'EEE', 'Male', '3155', 'below']
#   - [4.08, 'Sophie Fox', 'LKCMedicine', 'Female', '5568', 'average']
#
# Tutorial Group 'G-4', Group 6: Males = 1, Females = 4
#   - [4.15, 'Zainab Farooq', 'CCEB', 'Female', '2775', 'above']
#   - [4.15, 'Fatimah Abdullah', 'CoB (NBS)', 'Female', '5644', 'above']
#   - [3.95, 'Rongwei', 'SSS', 'Female', '3159', 'below']
#   - [3.9, 'Dmitry Orlov', 'CCDS', 'Male', '1734', 'below']
#   - [4.09, 'Hana Tan', 'CoE', 'Female', '345', 'average']
#
# Tutorial Group 'G-40', Group 10: Males = 4, Females = 1
#   - [4.12, 'Xavier Hall', 'SoH', 'Male', '5870', 'above']
#   - [4.12, 'Tam Vo', 'CEE', 'Male', '1988', 'above']
#   - [4.09, 'Daria Tan', 'EEE', 'Female', '5632', 'average']
#   - [3.91, 'Fedor Baranov', 'CoE', 'Male', '3390', 'below']
#   - [3.9, 'Zhao Yu Tan', 'CEE', 'Male', '208', 'below']
#
# Tutorial Group 'G-41', Group 9: Males = 4, Females = 1
#   - [4.15, 'Vinay Nair', 'CEE', 'Male', '1954', 'above']
#   - [4.15, 'Tariq Bin Ali', 'ADM', 'Male', '2038', 'above']
#   - [4.12, 'Ananya Verma', 'EEE', 'Female', '3010', 'average']
#   - [3.89, 'Shahid Waseem', 'CoE', 'Male', '3802', 'below']
#   - [4.1, 'Siddharth Rao', 'CCDS', 'Male', '3962', 'average']
#
# Tutorial Group 'G-42', Group 6: Males = 4, Females = 1
#   - [4.2, 'Cheng Yu', 'CCDS', 'Male', '3857', 'above']
#   - [4.19, 'Tristan King', 'SPMS', 'Male', '5592', 'above']
#   - [3.93, 'Mackenzie Dela Cruz', 'SSS', 'Female', '3131', 'below']
#   - [4.09, 'Ryan Yang', 'CoB (NBS)', 'Male', '4785', 'average']
#   - [3.93, 'Darren Lee', 'MSE', 'Male', '5270', 'below']
#
# Tutorial Group 'G-43', Group 10: Males = 1, Females = 4
#   - [4.1, 'Xia Yu', 'CCDS', 'Female', '1217', 'above']
#   - [4.1, 'Min Zhu', 'EEE', 'Female', '5812', 'above']
#   - [4.08, 'Ke Wang', 'CoE', 'Male', '5969', 'average']
#   - [4.02, 'Rina Sharma', 'EEE', 'Female', '2170', 'below']
#   - [4.06, 'Zara Latif', 'CCDS', 'Female', '667', 'average']
#
# Tutorial Group 'G-44', Group 10: Males = 1, Females = 4
#   - [4.14, 'Zoe Adams', 'SBS', 'Female', '4872', 'above']
#   - [4.14, 'Christian Peterson', 'MAE', 'Male', '4541', 'above']
#   - [4.12, 'Aria Smith', 'CCEB', 'Female', '5472', 'average']
#   - [4.11, 'Jin Xiu', 'SBS', 'Female', '702', 'average']
#   - [4.12, 'An Pham', 'SPMS', 'Female', '546', 'average']
#
# Tutorial Group 'G-45', Group 9: Males = 1, Females = 4
#   - [4.12, 'Hana Nishida', 'CCEB', 'Female', '3620', 'above']
#   - [4.12, 'Anu Rao', 'MAE', 'Female', '4659', 'above']
#   - [3.88, 'Alina Shah', 'CoB (NBS)', 'Female', '1376', 'below']
#   - [4.07, 'Vince Wong', 'NIE', 'Male', '1051', 'average']
#   - [3.7, 'Rachael Tan', 'SSS', 'Female', '1458', 'below']
#
# Tutorial Group 'G-46', Group 9: Males = 1, Females = 4
#   - [4.1, 'Fiona Lim', 'SPMS', 'Female', '442', 'above']
#   - [4.1, 'Dina Binti Azhar', 'SBS', 'Female', '5437', 'above']
#   - [4.05, 'Yong Wei Tan', 'WKW SCI', 'Male', '4162', 'average']
#   - [3.9, 'Isabella Wright', 'CoB (NBS)', 'Female', '5811', 'below']
#   - [3.9, 'Elizaveta Semyonova', 'CoB (NBS)', 'Female', '3279', 'below']
#
# Tutorial Group 'G-47', Group 7: Males = 4, Females = 1
#   - [4.15, 'Finn Liu', 'CoE', 'Male', '5267', 'above']
#   - [4.14, 'Rajiv Singh', 'MAE', 'Male', '1399', 'above']
#   - [4.03, 'Nora Turner', 'SPMS', 'Female', '2467', 'average']
#   - [3.95, 'James Lewis', 'CoE', 'Male', '5872', 'below']
#   - [3.91, 'Samuel White', 'WKW SCI', 'Male', '1681', 'below']
#
# Tutorial Group 'G-48', Group 10: Males = 1, Females = 4
#   - [4.14, 'Nitin Mehta', 'CoB (NBS)', 'Male', '1432', 'above']
#   - [4.14, 'Hannah King', 'SSS', 'Female', '5930', 'above']
#   - [4.11, 'Freya Brown', 'CCEB', 'Female', '777', 'average']
#   - [4.0, 'Jasmine Chan', 'SSS', 'Female', '501', 'below']
#   - [4.0, 'Aldina Putri', 'SoH', 'Female', '5613', 'below']
#
# Tutorial Group 'G-5', Group 3: Males = 1, Females = 4
#   - [4.22, 'Dorian Wu', 'SPMS', 'Male', '2801', 'above']
#   - [4.21, 'Nisha Tan', 'CoB (NBS)', 'Female', '5658', 'above']
#   - [4.01, 'Shu Zhang', 'CoB (NBS)', 'Female', '5044', 'below']
#   - [4.01, 'Olive Li', 'CCDS', 'Female', '3341', 'below']
#   - [4.11, 'Sophie Zhou', 'EEE', 'Female', '554', 'average']
#
# Tutorial Group 'G-5', Group 6: Males = 1, Females = 4
#   - [4.19, 'Rina Sato', 'MSE', 'Female', '4569', 'above']
#   - [4.18, 'Wendy Wong', 'CCDS', 'Female', '1336', 'above']
#   - [3.95, 'Priya Rao', 'LKCMedicine', 'Female', '4015', 'below']
#   - [3.95, 'Exiang', 'EEE', 'Male', '2316', 'below']
#   - [4.07, 'Yue Zhang', 'SSS', 'Female', '1246', 'average']
#
# Tutorial Group 'G-51', Group 10: Males = 1, Females = 4
#   - [4.14, 'Gabriel Navarro', 'EEE', 'Male', '5589', 'above']
#   - [4.12, 'Min Xu', 'EEE', 'Female', '804', 'above']
#   - [4.05, 'Rina Binti Khairul', 'CCDS', 'Female', '4632', 'average']
#   - [4.08, 'Emily Turner', 'CCEB', 'Female', '8', 'average']
#   - [4.06, 'Jasmine Tan', 'SSS', 'Female', '2968', 'average']
#
# Tutorial Group 'G-54', Group 10: Males = 1, Females = 4
#   - [4.15, 'Miranda Wang', 'ADM', 'Female', '1079', 'above']
#   - [4.15, 'Emma Wang', 'LKCMedicine', 'Female', '4594', 'above']
#   - [3.87, 'Sophie Sanders', 'SSS', 'Female', '4301', 'below']
#   - [4.1, 'Hieu Nguyen', 'EEE', 'Male', '2676', 'average']
#   - [4.04, 'Anya Dela Cruz', 'SoH', 'Female', '2641', 'below']
#
# Tutorial Group 'G-56', Group 7: Males = 1, Females = 4
#   - [4.12, 'Lydia Young', 'SPMS', 'Female', '1741', 'above']
#   - [4.12, 'Florence Ong', 'SSS', 'Female', '5293', 'above']
#   - [3.92, 'Lai Thi Ngan', 'CoB (NBS)', 'Female', '1832', 'below']
#   - [3.9, 'Ulysses Wong', 'WKW SCI', 'Male', '5795', 'below']
#   - [4.05, 'Fengyi', 'EEE', 'Female', '4454', 'average']
#
# Tutorial Group 'G-6', Group 10: Males = 1, Females = 4
#   - [4.14, 'Henry Ramirez', 'SPMS', 'Male', '5426', 'above']
#   - [4.12, 'Harper Hall', 'SoH', 'Female', '1641', 'above']
#   - [4.05, 'Umi Lestari', 'EEE', 'Female', '4311', 'average']
#   - [4.02, 'Aubrey Carter', 'MSE', 'Female', '4390', 'below']
#   - [3.95, 'Clara Tan', 'CoB (NBS)', 'Female', '4345', 'below']
#
# Tutorial Group 'G-68', Group 10: Males = 1, Females = 4
#   - [4.12, 'Sophie Turner', 'NIE', 'Female', '2530', 'above']
#   - [4.12, 'Song-Joo Lee', 'CoB (NBS)', 'Female', '1714', 'above']
#   - [4.05, 'Leona Chua', 'CoB (NBS)', 'Female', '4276', 'average']
#   - [4.0, 'Riley Adams', 'SPMS', 'Male', '1576', 'below']
#   - [4.01, 'Maya Ramirez', 'SBS', 'Female', '3762', 'below']
#
# Tutorial Group 'G-70', Group 8: Males = 1, Females = 4
#   - [4.15, 'Aifang', 'SSS', 'Female', '4424', 'above']
#   - [4.14, 'Zachary Wu', 'NIE', 'Male', '1125', 'above']
#   - [3.9, 'Jasmine Binti Ali', 'CCDS', 'Female', '1843', 'below']
#   - [3.9, 'Aarvi Gupta', 'MSE', 'Female', '5392', 'below']
#   - [4.01, 'Ella Rodriguez', 'SSS', 'Female', '4808', 'below']
#
# Tutorial Group 'G-70', Group 10: Males = 1, Females = 4
#   - [4.13, 'Maya Evans', 'MSE', 'Female', '5054', 'above']
#   - [4.12, 'Nimisha Gupta', 'CCDS', 'Female', '5636', 'above']
#   - [4.1, 'Emma Thomas', 'SoH', 'Female', '5631', 'average']
#   - [4.02, 'Jack Ng', 'EEE', 'Male', '3766', 'below']
#   - [4.1, 'Cary Tan', 'NIE', 'Female', '1093', 'average']
#
# Tutorial Group 'G-71', Group 10: Males = 1, Females = 4
#   - [4.15, 'Hira Ali', 'EEE', 'Female', '2460', 'above']
#   - [4.14, 'Mohammad Ali', 'CoB (NBS)', 'Male', '3433', 'above']
#   - [4.08, 'Lila Martinez', 'CCEB', 'Female', '1713', 'average']
#   - [4.04, 'Monique Fernandez', 'WKW SCI', 'Female', '1808', 'below']
#   - [4.04, 'Maya Iyer', 'MAE', 'Female', '1270', 'below']
#
# Tutorial Group 'G-8', Group 10: Males = 4, Females = 1
#   - [4.12, 'Zane Carter', 'SoH', 'Male', '3623', 'above']
#   - [4.12, 'Thao Le', 'CCDS', 'Male', '2374', 'above']
#   - [4.1, 'Poppy Cahyani', 'CCDS', 'Female', '593', 'average']
#   - [4.02, 'Seung-Jin Han', 'CoB (NBS)', 'Male', '5515', 'below']
#   - [3.89, 'Mason Hughes', 'CoB (NBS)', 'Male', '1708', 'below']
#
# Tutorial Group 'G-84', Group 10: Males = 1, Females = 4
#   - [4.19, 'Elena Chang', 'SBS', 'Female', '4032', 'above']
#   - [4.18, 'Bodhi Edwards', 'CCDS', 'Male', '2908', 'above']
#   - [4.14, 'Xue Mei', 'EEE', 'Female', '3194', 'average']
#   - [4.11, 'Kiran Menon', 'SPMS', 'Female', '1993', 'average']
#   - [4.11, 'Li Mei', 'SSS', 'Female', '323', 'average']
#
# Tutorial Group 'G-88', Group 10: Males = 1, Females = 4
#   - [4.14, 'Fei Wang', 'LKCMedicine', 'Male', '2062', 'above']
#   - [4.14, 'Eleanor Hayes', 'SBS', 'Female', '2434', 'above']
#   - [4.09, 'Kavya Nair', 'CoB (NBS)', 'Female', '1296', 'average']
#   - [4.0, 'Liangyu', 'SoH', 'Female', '2342', 'below']
#   - [4.08, 'Daphne Tsai', 'EEE', 'Female', '3864', 'average']
#
# Tutorial Group 'G-9', Group 10: Males = 4, Females = 1
#   - [4.09, 'Ravi Kumar', 'CoB (NBS)', 'Male', '1890', 'above']
#   - [4.09, 'Fumiko Yamashita', 'ASE', 'Female', '4953', 'above']
#   - [4.06, 'Liam Tan', 'SBS', 'Male', '2642', 'average']
#   - [4.08, 'Bryan Villanueva', 'CCDS', 'Male', '1158', 'average']
#   - [4.05, 'Umar Faisal', 'NIE', 'Male', '4012', 'average']
#
# Tutorial Group 'G-92', Group 10: Males = 1, Females = 4
#   - [4.17, 'Erica Chen', 'CoB (NBS)', 'Female', '2304', 'above']
#   - [4.16, 'Tatiana Ivanovna', 'SSS', 'Female', '4344', 'above']
#   - [4.1, 'Carter Young', 'EEE', 'Male', '3023', 'average']
#   - [4.12, 'Aria Patel', 'SoH', 'Female', '1189', 'average']
#   - [4.09, 'Abigail Lee', 'EEE', 'Female', '99', 'average']
#
# Tutorial Group 'G-94', Group 7: Males = 1, Females = 4
#   - [4.15, 'Cindy Tan', 'MAE', 'Female', '1751', 'above']
#   - [4.15, 'Chloe Davis', 'MAE', 'Female', '241', 'above']
#   - [4.0, 'Charlotte Foster', 'CEE', 'Female', '2437', 'below']
#   - [4.1, 'Kade Wu', 'LKCMedicine', 'Male', '5179', 'average']
#   - [3.95, 'Paola Santos', 'CoE', 'Female', '998', 'below']
#
# Tutorial Group 'G-94', Group 10: Males = 1, Females = 4
#   - [4.12, 'Pallavi Reddy', 'MAE', 'Female', '3637', 'above']
#   - [4.12, 'Jackson Allen', 'CoE', 'Male', '2499', 'above']
#   - [4.06, 'Riya Kapoor', 'MSE', 'Female', '797', 'average']
#   - [4.03, 'Shan Mei', 'MAE', 'Female', '3495', 'below']
#   - [3.91, 'Chloe Robinson', 'MAE', 'Female', '5484', 'below']
#
# Tutorial Group 'G-97', Group 3: Males = 1, Females = 4
#   - [4.25, 'Mei Liu', 'SSS', 'Female', '1707', 'above']
#   - [4.21, 'Maya Chua', 'SBS', 'Female', '5239', 'above']
#   - [4.01, 'Kaira Lim', 'CCDS', 'Female', '4757', 'below']
#   - [4.12, 'Chao Zhang', 'CoB (NBS)', 'Male', '3266', 'average']
#   - [4.01, 'Jasmine Wong', 'MAE', 'Female', '3917', 'below']
#
# Tutorial Group 'G-97', Group 9: Males = 1, Females = 4
#   - [4.17, 'Bodhi Yang', 'SPMS', 'Male', '4602', 'above']
#   - [4.16, 'Ayesha Siddiqui', 'CCEB', 'Female', '935', 'above']
#   - [3.86, 'Jin-Ah Kim', 'CCDS', 'Female', '3336', 'below']
#   - [3.86, 'Aria Thompson', 'SBS', 'Female', '863', 'below']
#   - [4.0, 'Mei Xuan Tan', 'CoB (NBS)', 'Female', '1924', 'below']
# 64

# %% [markdown]
# ## Challenges and Issues
#
# ### Challenges Faced
# 1. **Gender and GPA Distribution**: Balancing gender distribution while grouping by GPA ranges.
# 2. **Constraint Fulfillment**: Maintaining constraints in groups with an uneven number of students.
#
# ### Solutions
# We introduced a reserve list to handle ungrouped students, refining the algorithm to respect constraints while optimizing group sizes and diversity.

# %% [markdown]
# ## Computational Thinking Reflection(Summary)
#
# ### Decomposition
# We divided the problem into manageable tasks (data loading, grouping, sorting, and constraint handling).
#
# ### Pattern Recognition
# We identified patterns in student GPA and gender, which helped optimize sorting.
#
# ### Abstraction
# Focused only on relevant attributes (GPA, gender, school) to simplify logic.
#
# ### Algorithm Design
# The modular design of the code facilitated efficient constraint management and flexibility.

# %% [markdown]
# ### Analysis of Data
#
#
# Below is the code for the calculation of standard deviation of GPAs, as well as absolute difference of Females and Males in each subgroup.

# %%
import csv
from math import sqrt

# Load the CSV file
csvlist = []
with open("C:\\Users\\jesmo\\OneDrive\\Documents\\FCSF_Team2_JesmondTaySoonXiang\\FCSF_Team2_JesmondTaySoonXiang.csv") as file:
    csv_reader = csv.reader(file)
    for lines in csv_reader:
        csvlist.append(lines)

# Create dictionaries to store gender counts and GPA
gender_counts = {}
gpa_data = {}

for row in csvlist[1:]:
    tutorial_group = row[0]  # Tutorial Group
    group_number = row[6]         # Group Number
    gender = row[4]           # Gender
    try:
        gpa = float(row[5])    # GPA
    except ValueError:
        continue  # Skip non-numeric values

    # Organize gender counts
    if tutorial_group not in gender_counts:
        gender_counts[tutorial_group] = {}
    if group_number not in gender_counts[tutorial_group]:
        gender_counts[tutorial_group][group_number] = {'Male': 0, 'Female': 0}
    if gender in gender_counts[tutorial_group][group_number]:
        gender_counts[tutorial_group][group_number][gender] += 1

    # Collect GPAs for statistics
    if tutorial_group not in gpa_data:
        gpa_data[tutorial_group] = {}
    if group_number not in gpa_data[tutorial_group]:
        gpa_data[tutorial_group][group_number] = []
    gpa_data[tutorial_group][group_number].append(gpa)

combined_identifiers = [] 
# Print gender counts and modulus difference, and calculate GPA statistics
for tutorial_group, group_numbers in gender_counts.items():
    print(f"Tutorial Group: {tutorial_group}")
    for group_number, counts in group_numbers.items():
        # Calculate absolute difference
        absolute_difference = abs(counts['Female'] - counts['Male'])
        print(f"  Group Number: {group_number} | Males: {counts['Male']} | Females: {counts['Female']} | Absolute Difference: {absolute_difference}")

        # Calculate mean and standard deviation for GPA
        gpas = gpa_data[tutorial_group][group_number]
        mean = sum(gpas) / len(gpas) if gpas else 0
        variance = sum((x - mean) ** 2 for x in gpas) / len(gpas) if gpas else 0
        std_dev = sqrt(variance)

        print(f"    Mean GPA: {mean:.2f} | Standard Deviation: {std_dev:.3f}")

        # Create combined identifier
        combined_identifier = f"{tutorial_group}-{group_number}"
        combined_identifiers.append(combined_identifier)
# Out:
# Tutorial Group: G-1
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.076
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.135
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.076
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.077
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.25 | Standard Deviation: 0.209
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.085
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.088
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.082
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.097
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.088
# Tutorial Group: G-10
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.26 | Standard Deviation: 0.213
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.119
#   Group Number: 6 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.078
#   Group Number: 10 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.07 | Standard Deviation: 0.096
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.065
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.093
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.081
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.083
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.15 | Standard Deviation: 0.093
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.070
# Tutorial Group: G-100
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.080
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.083
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.109
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.069
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.072
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.20 | Standard Deviation: 0.179
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.107
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.072
#   Group Number: 6 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.069
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.097
# Tutorial Group: G-101
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.087
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.076
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.073
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.078
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.097
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.19 | Standard Deviation: 0.163
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.00 | Standard Deviation: 0.131
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.101
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.132
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.26 | Standard Deviation: 0.200
# Tutorial Group: G-102
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.081
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.068
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.141
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.070
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.031
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.096
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.111
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.091
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.076
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.085
# Tutorial Group: G-103
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.108
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.132
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.125
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.115
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.22 | Standard Deviation: 0.164
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.082
#   Group Number: 6 | Males: 4 | Females: 1 | Absolute Difference: 3
#     Mean GPA: 4.10 | Standard Deviation: 0.079
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.15 | Standard Deviation: 0.085
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.081
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.077
# Tutorial Group: G-104
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.070
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.084
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.072
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.096
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.069
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.082
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.085
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.075
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.034
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.106
# Tutorial Group: G-105
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.067
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.063
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.129
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.135
#   Group Number: 10 | Males: 5 | Females: 0 | Absolute Difference: 5
#     Mean GPA: 4.06 | Standard Deviation: 0.086
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.074
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.080
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.17 | Standard Deviation: 0.096
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.089
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.084
# Tutorial Group: G-106
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.078
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.082
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.116
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.21 | Standard Deviation: 0.183
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.088
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.079
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.078
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.117
#   Group Number: 10 | Males: 4 | Females: 1 | Absolute Difference: 3
#     Mean GPA: 4.07 | Standard Deviation: 0.070
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.104
# Tutorial Group: G-107
#   Group Number: 10 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.07 | Standard Deviation: 0.045
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.095
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.107
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.099
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.119
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.083
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.140
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.110
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.00 | Standard Deviation: 0.120
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.089
# Tutorial Group: G-108
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.088
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.25 | Standard Deviation: 0.245
#   Group Number: 6 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.08 | Standard Deviation: 0.093
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.078
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 3.99 | Standard Deviation: 0.129
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.093
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.114
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.081
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.083
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.091
# Tutorial Group: G-109
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.139
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.092
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.090
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.066
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.112
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.089
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.116
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.124
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.096
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.106
# Tutorial Group: G-11
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.149
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.095
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.15 | Standard Deviation: 0.125
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.106
#   Group Number: 10 | Males: 4 | Females: 1 | Absolute Difference: 3
#     Mean GPA: 4.06 | Standard Deviation: 0.043
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.099
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.119
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.00 | Standard Deviation: 0.132
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.092
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.090
# Tutorial Group: G-110
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.088
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.067
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.078
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.067
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.071
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.081
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.066
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.098
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.070
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.038
# Tutorial Group: G-111
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.095
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.21 | Standard Deviation: 0.183
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.092
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.00 | Standard Deviation: 0.130
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.070
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.144
#   Group Number: 6 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.101
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.15 | Standard Deviation: 0.111
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.085
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.140
# Tutorial Group: G-112
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.075
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.065
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.125
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.23 | Standard Deviation: 0.165
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.077
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.074
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.072
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.090
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.120
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.067
# Tutorial Group: G-113
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.072
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.076
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.127
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.00 | Standard Deviation: 0.110
#   Group Number: 10 | Males: 4 | Females: 1 | Absolute Difference: 3
#     Mean GPA: 4.01 | Standard Deviation: 0.118
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.077
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 3.99 | Standard Deviation: 0.137
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.090
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.069
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.113
# Tutorial Group: G-114
#   Group Number: 8 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.06 | Standard Deviation: 0.075
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.057
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.079
#   Group Number: 5 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.04 | Standard Deviation: 0.117
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.074
#   Group Number: 10 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.04 | Standard Deviation: 0.083
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.064
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.23 | Standard Deviation: 0.218
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.077
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.097
# Tutorial Group: G-115
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.076
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.072
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.16 | Standard Deviation: 0.091
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.070
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.139
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.076
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.128
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.076
#   Group Number: 9 | Males: 4 | Females: 1 | Absolute Difference: 3
#     Mean GPA: 4.08 | Standard Deviation: 0.097
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.052
# Tutorial Group: G-116
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.00 | Standard Deviation: 0.137
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.074
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.16 | Standard Deviation: 0.120
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.109
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.106
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.107
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.085
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.081
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.24 | Standard Deviation: 0.213
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.033
# Tutorial Group: G-117
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.077
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.075
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.085
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.15 | Standard Deviation: 0.098
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.076
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.103
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.25 | Standard Deviation: 0.258
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.126
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.081
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.113
# Tutorial Group: G-118
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.080
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.21 | Standard Deviation: 0.189
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.050
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.141
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.131
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.116
#   Group Number: 6 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.100
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.099
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.090
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.109
# Tutorial Group: G-119
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.066
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.072
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.15 | Standard Deviation: 0.099
#   Group Number: 10 | Males: 4 | Females: 1 | Absolute Difference: 3
#     Mean GPA: 4.03 | Standard Deviation: 0.127
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.123
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.128
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.067
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.065
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.080
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.068
# Tutorial Group: G-12
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.039
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.16 | Standard Deviation: 0.099
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.142
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.125
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.25 | Standard Deviation: 0.224
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.106
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.101
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.092
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.083
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.123
# Tutorial Group: G-120
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.083
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.18 | Standard Deviation: 0.190
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.090
#   Group Number: 10 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.07 | Standard Deviation: 0.059
#   Group Number: 6 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.076
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.074
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.26 | Standard Deviation: 0.231
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.078
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.070
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.068
# Tutorial Group: G-13
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.106
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.096
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.101
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.116
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.053
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.090
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.115
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.095
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.106
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 3.97 | Standard Deviation: 0.123
# Tutorial Group: G-14
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.102
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.040
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.103
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.19 | Standard Deviation: 0.192
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.088
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.145
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.140
#   Group Number: 6 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.117
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.031
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.118
# Tutorial Group: G-15
#   Group Number: 6 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.099
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.107
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.080
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.083
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.101
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.119
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.088
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.093
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.072
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.079
# Tutorial Group: G-16
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.100
#   Group Number: 10 | Males: 4 | Females: 1 | Absolute Difference: 3
#     Mean GPA: 4.00 | Standard Deviation: 0.111
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.076
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.081
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.104
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.067
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.075
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.068
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.081
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.17 | Standard Deviation: 0.167
# Tutorial Group: G-17
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.20 | Standard Deviation: 0.182
#   Group Number: 8 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.02 | Standard Deviation: 0.112
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.081
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.078
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.108
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.081
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.111
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.098
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.094
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.077
# Tutorial Group: G-18
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.078
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.100
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.089
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.077
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.078
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.114
#   Group Number: 7 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.03 | Standard Deviation: 0.113
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.124
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.074
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.114
# Tutorial Group: G-19
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.068
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.046
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.125
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.108
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.105
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.063
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.071
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.091
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.052
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.072
# Tutorial Group: G-2
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.072
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.070
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.072
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.074
#   Group Number: 9 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.03 | Standard Deviation: 0.117
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.082
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.085
#   Group Number: 4 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.10 | Standard Deviation: 0.075
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.046
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.076
# Tutorial Group: G-20
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.042
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.083
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.049
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.088
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.19 | Standard Deviation: 0.191
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.102
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.090
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.120
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.105
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.130
# Tutorial Group: G-21
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.117
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.078
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.098
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.106
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.115
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.053
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.080
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.082
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.098
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.119
# Tutorial Group: G-22
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.081
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.111
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.082
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.131
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.080
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.077
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.041
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.082
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.091
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.095
# Tutorial Group: G-23
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.099
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.119
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.27 | Standard Deviation: 0.283
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.111
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.076
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.081
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.116
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.117
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.102
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.128
# Tutorial Group: G-24
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.076
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.105
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.035
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 3.96 | Standard Deviation: 0.116
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.088
#   Group Number: 6 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.078
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.088
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.079
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.080
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.099
# Tutorial Group: G-25
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.079
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.134
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.070
#   Group Number: 7 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.05 | Standard Deviation: 0.104
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.021
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.106
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.084
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.22 | Standard Deviation: 0.262
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.077
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.091
# Tutorial Group: G-26
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.108
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.085
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.131
#   Group Number: 10 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.02 | Standard Deviation: 0.107
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.15 | Standard Deviation: 0.115
#   Group Number: 9 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.05 | Standard Deviation: 0.092
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.094
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.112
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.102
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.093
# Tutorial Group: G-27
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.21 | Standard Deviation: 0.181
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.031
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.106
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.095
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.122
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.180
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.087
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.128
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.119
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.114
# Tutorial Group: G-28
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.106
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.121
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
# ...
#     Mean GPA: 4.03 | Standard Deviation: 0.119
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.050
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.091
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.084
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.27 | Standard Deviation: 0.229
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.079
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.030
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.080
# Tutorial Group: G-88
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.077
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.086
#   Group Number: 6 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.072
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.114
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.081
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.078
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.077
#   Group Number: 10 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.09 | Standard Deviation: 0.051
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.131
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.086
# Tutorial Group: G-89
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.124
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 3.99 | Standard Deviation: 0.135
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.118
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.121
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.095
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.081
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.18 | Standard Deviation: 0.171
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.085
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.114
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.107
# Tutorial Group: G-9
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.077
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.081
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.082
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.097
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.19 | Standard Deviation: 0.172
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.072
#   Group Number: 10 | Males: 4 | Females: 1 | Absolute Difference: 3
#     Mean GPA: 4.07 | Standard Deviation: 0.016
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.085
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.108
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.108
# Tutorial Group: G-90
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.080
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.085
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.00 | Standard Deviation: 0.115
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.075
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.081
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.109
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.18 | Standard Deviation: 0.189
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.098
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.038
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.112
# Tutorial Group: G-91
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.063
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.106
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.128
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.15 | Standard Deviation: 0.098
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.076
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.067
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.068
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.070
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.121
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.097
# Tutorial Group: G-92
#   Group Number: 10 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.13 | Standard Deviation: 0.032
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.121
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.093
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.095
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.16 | Standard Deviation: 0.081
#   Group Number: 6 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.101
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.089
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.118
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.115
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.106
# Tutorial Group: G-93
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.080
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.080
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.33 | Standard Deviation: 0.281
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.050
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.21 | Standard Deviation: 0.155
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.095
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.075
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.144
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.107
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.085
# Tutorial Group: G-94
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.072
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.134
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.084
#   Group Number: 7 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.07 | Standard Deviation: 0.081
#   Group Number: 10 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.05 | Standard Deviation: 0.077
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.071
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.128
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.065
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.069
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.19 | Standard Deviation: 0.162
# Tutorial Group: G-95
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.122
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.21 | Standard Deviation: 0.247
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.12 | Standard Deviation: 0.131
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.112
#   Group Number: 6 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.121
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.089
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.061
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 3.98 | Standard Deviation: 0.130
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.098
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.119
# Tutorial Group: G-96
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.18 | Standard Deviation: 0.190
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.00 | Standard Deviation: 0.119
#   Group Number: 3 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.074
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.093
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.078
#   Group Number: 10 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.056
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.07 | Standard Deviation: 0.067
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.072
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.083
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.02 | Standard Deviation: 0.106
# Tutorial Group: G-97
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.118
#   Group Number: 10 | Males: 0 | Females: 5 | Absolute Difference: 5
#     Mean GPA: 4.06 | Standard Deviation: 0.088
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.130
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.131
#   Group Number: 9 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.01 | Standard Deviation: 0.137
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.090
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.111
#   Group Number: 3 | Males: 1 | Females: 4 | Absolute Difference: 3
#     Mean GPA: 4.12 | Standard Deviation: 0.099
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.132
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.15 | Standard Deviation: 0.113
# Tutorial Group: G-98
#   Group Number: 4 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.085
#   Group Number: 5 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.082
#   Group Number: 6 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.074
#   Group Number: 1 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.19 | Standard Deviation: 0.191
#   Group Number: 2 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.14 | Standard Deviation: 0.110
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.103
#   Group Number: 7 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.092
#   Group Number: 9 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.098
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.11 | Standard Deviation: 0.105
#   Group Number: 8 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.04 | Standard Deviation: 0.109
# Tutorial Group: G-99
#   Group Number: 6 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.05 | Standard Deviation: 0.077
#   Group Number: 8 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.01 | Standard Deviation: 0.103
#   Group Number: 7 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.03 | Standard Deviation: 0.088
#   Group Number: 3 | Males: 3 | Females: 2 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.075
#   Group Number: 5 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.08 | Standard Deviation: 0.067
#   Group Number: 1 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.13 | Standard Deviation: 0.114
#   Group Number: 10 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.06 | Standard Deviation: 0.028
#   Group Number: 9 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.00 | Standard Deviation: 0.116
#   Group Number: 2 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.10 | Standard Deviation: 0.103
#   Group Number: 4 | Males: 2 | Females: 3 | Absolute Difference: 1
#     Mean GPA: 4.09 | Standard Deviation: 0.078

# %% [markdown]
# Below is the code for the plotting of the following graphs:
# 1. 3D scatter plot of Assigned Group Fairness
# 2. Bar chart of Absolute Difference (Female-Male) in each Subgroup
# 3. Bar chart of Number of Unique Schools in each Subgroup
# 4. Bar chart of Standard Deviation of GPAs in each Subgroup

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches  # For the legend


# Create dictionaries to store gender counts, GPA data, and school variety
gender_counts = {}
gpa_data = {}
school_variety = {}

with open("C:\\Users\\jesmo\\OneDrive\\Documents\\FCSF_Team2_JesmondTaySoonXiang\\FCSF_Team2_JesmondTaySoonXiang.csv", mode='r') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        tutorial_group, group_number, gender, school = row[0], row[6], row[4], row[2]
        try:
            gpa = float(row[5])
        except ValueError:
            continue  # Skip non-numeric GPA values

        # Ensure necessary dictionaries exist for gender counts, GPA data, and school variety
        if tutorial_group not in gender_counts:
            gender_counts[tutorial_group] = {}
        if group_number not in gender_counts[tutorial_group]:
            gender_counts[tutorial_group][group_number] = {'Male': 0, 'Female': 0}

        if tutorial_group not in gpa_data:
            gpa_data[tutorial_group] = {}
        if group_number not in gpa_data[tutorial_group]:
            gpa_data[tutorial_group][group_number] = []

        if tutorial_group not in school_variety:
            school_variety[tutorial_group] = {}
        if group_number not in school_variety[tutorial_group]:
            school_variety[tutorial_group][group_number] = set()

        # Update the data
        gender_counts[tutorial_group][group_number][gender] += 1
        gpa_data[tutorial_group][group_number].append(gpa)
        school_variety[tutorial_group][group_number].add(school)

# Prepare data for plotting
x, y, z, colors = [], [], [], []
absolute_differences = []  # To hold modulus differences for bar graph
unique_schools_counts = []  # To hold counts of unique schools
std_dev_gpas = []           # To hold standard deviations of GPAs
labels = []                 # Labels for each bar
distinct_values = {1: 'red', 3: 'green', 5: 'blue'}

# Process the data for plotting
for tutorial_group, groups in gender_counts.items():
    for group_number, counts in groups.items():
        # Modulus difference and color
        modulus_difference = abs(counts['Female'] - counts['Male'])
        color = distinct_values.get(modulus_difference)
        colors.append(color)
        absolute_differences.append(modulus_difference)

        # GPA standard deviation
        gpas = gpa_data[tutorial_group][group_number]
        mean = sum(gpas) / len(gpas) if gpas else 0
        std_dev = sqrt(sum((x - mean) ** 2 for x in gpas) / len(gpas)) if gpas else 0
        std_dev_gpas.append(std_dev)

        # Unique schools
        unique_schools = len(school_variety[tutorial_group][group_number])
        unique_schools_counts.append(unique_schools)

        # Prepare x and label
        y.append(unique_schools)
        x.append(f"{tutorial_group}-{group_number}")
        labels.append(f"{tutorial_group}-{group_number}")

# Convert combined identifiers to numerical values for plotting
x_numerical = list(range(len(x)))

# Create 3D scatter plot
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(x_numerical, y, std_dev_gpas, c=colors)
ax.set_xlabel('Subgroups in Tutorial Group')
ax.set_ylabel('Number of Unique Schools')
ax.set_zlabel('Standard Deviation of GPA', labelpad=1)

# Add title  
plt.title('3D Scatter Plot of Assigned Group Fairness')

# Create the legend for colors
legend_labels = {1: '1', 3: '3', 5: '5'}  
handles = [mpatches.Patch(color=color, label=legend_labels.get(modulus, f"Modulus {modulus}")) 
           for modulus, color in distinct_values.items()]
plt.legend(handles=handles, title="Absolute Difference (Female - Male) per Subgroup")

# Show the 3D scatter plot
plt.show()

# Create bar chart for modulus differences
plt.figure(figsize=(12, 6))
plt.bar(labels, absolute_differences, color='lightgreen')
plt.xticks([])  # Removes tick marks and labels
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.xlabel('Subgroups in Tutorial Group')
plt.ylabel('Absolute Difference (Female - Male)')
plt.title('Absolute Difference (Female - Male) per Subgroup')
plt.tight_layout()
plt.show()

# Create bar chart for unique schools
plt.figure(figsize=(12, 6))
plt.bar(labels, unique_schools_counts, color='skyblue')
plt.xticks([])  # Removes tick marks and labels
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.xlabel('Subgroups in Tutorial Group')
plt.ylabel('Number of Unique Schools')
plt.title('Number of Unique Schools per Subgroup')
plt.tight_layout()
plt.show()

# Create bar chart for standard deviations of GPAs
plt.figure(figsize=(12, 6))
plt.bar(labels, std_dev_gpas, color='salmon')
plt.xticks([])  # Removes tick marks and labels
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.xlabel('Subgroups in Tutorial Group')
plt.ylabel('Standard Deviation of GPA')
plt.title('Standard Deviation of GPA per Subgroup')
plt.tight_layout()
plt.show()

# %% [markdown]
# |Full Name    | Date   | A or B|
# | --------    | -------|-------|
# | LEE ZHE CHIAN   |  15/11/24  |A|
# | JESMOND TAY SOON XIANG | 15/11/24  |B|
# | LEE ZHENG JIE    | 15/11/24 |A|
# | KATTA ROHITA | 15/11/24 |A|
# | HTET MOE HAN | 15/11/24|B|

# %% [markdown]
# 1. Jesmond Tay Soon Xiang
# 2. Name of AI tool: Chatgpt
# 3. Input Prompt: "Where did i get wrong for my first sorting"
# 4. Date generated:1/11/24
# 5. Ouput generated:
#
#  "Your function is well-structured for sorting students by GPA categories while enforcing school and gender constraints. However, there are a few areas where we can make it more efficient and ensure it properly respects the constraints.
#
# Key Issues and Simplifications:
# Current Student Checks:
#
# Right now, if a student doesn’t fit the school or gender constraints, they are still being added to the group and then removed (pop() and re-added). We can adjust the logic so that a student only gets added if they meet the requirements.
# Use continue to Retry Selection:
#
# If a student doesn’t meet the school or gender requirements, you can use continue to retry the selection logic without popping and re-adding them.
# Fix Variable Names and Consistency:
#
# There’s a typo with reserve_dict (it should be consistent with the input name reserved_dict), which could lead to errors."
# Output Screenshot:![image.png](attachment:image.png)
#
# 6. Imapact on submission: I used it to assist with debugging and it helped to clarify some problems and syntax errors in my code.

# %% [markdown]
# - Name: HTET MOE HAN
# - Name of AI tool: 	ChatGPT
# - Input prompt: How to create a 3D scatter plot using Matplotlib?
# - Date generated: 	 30/10/24
# - Output generated: 	import matplotlib.pyplot as plt
#   from mpl_toolkits.mplot3d import Axes3D
#
#   Prepare your data for the x, y, and z axes
#   x = []  # List of x values
#   y = []  # List of y values
#   z = []  # List of z values
#   colors = []  # List of colors for each point (optional)
#
#   Create the figure and the 3D axis
#   fig = plt.figure(figsize=(width, height))
#   ax = fig.add_subplot(111, projection='3d')
#
#   Plot the data using scatter
#   scatter = ax.scatter(x, y, z, c=colors)
#
#   Set axis labels
#   ax.set_xlabel('X axis label')
#   ax.set_ylabel('Y axis label')
#   ax.set_zlabel('Z axis label')
#
#   Add a title
#   plt.title('3D Scatter Plot Title')
#
#   Show the plot
#   plt.show()
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)![image-3.png](attachment:image-3.png)
# - Impact on submission:The output generated from ChatGPT was modified accordingly and used during the algorithm analysis (generating the graphs) portion of the report.
#
# - Input prompt: How to create a bar chart using Matplotlib?
# - Date generated: 	 30/10/24
# - Ouput generated:
# import matplotlib.pyplot as plt
#
# Prepare your data for the bar chart
# labels = []  # List of labels for each bar (e.g., subgroups or categories)
# values = []  # List of values (e.g., counts or measurements)
#
# Create the bar chart
# plt.figure(figsize=(width, height))  # Optional: set the figure size
# plt.bar(labels, values, color='color')  # Color can be any valid matplotlib color
#
# Set labels and title
# plt.xlabel('X axis label')  # Label for the x-axis
# plt.ylabel('Y axis label')  # Label for the y-axis
# plt.title('Bar Chart Title')  # Title for the chart
#
# Show the plot
# plt.tight_layout()  # Optional: Adjust layout to prevent clipping
# plt.show()
#
# ![image-4.png](attachment:image-4.png)![image-5.png](attachment:image-5.png)
# - Impact on submission: The output generated from ChatGPT was modified accordingly and used during the algorithm analysis (generating the graphs) portion of the report.
